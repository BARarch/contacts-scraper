# %%
cc.VerificationHandler.close_browser()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-128-69f17e8e2e5a> in <module>()
# ----> 1 cc.VerificationHandler.close_browser()
#
# C:\Users\Anthony\scripts\Contacts-Scraper\contactChecker.py in close_browser(cls)
#     321         @classmethod
#     322         def close_browser(cls):
# --> 323                 VerificationHandler.orgRecords.close_session_browser()
#     324
#     325
#
# C:\Users\Anthony\scripts\Contacts-Scraper\directoryManager.py in close_session_browser(self)
#     178
#     179         def close_session_browser(self):
# --> 180                 self.sessionBrowser.close()
#     181
#     182 class BatchSessionPing(OrgSession):
#
# C:\Users\Anthony\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     580             driver.close()
#     581         """
# --> 582         self.execute(Command.CLOSE)
#     583
#     584     def quit(self):
#
# C:\Users\Anthony\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
# --> 297             self.error_handler.check_response(response)
#     298             response['value'] = self._unwrap_value(
#     299                 response.get('value', None))
#
# C:\Users\Anthony\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: no such session
#   (Driver info: chromedriver=2.32.498550 (9dec58e66c31bcc53a9ce3c7226f0c1c5810906a),platform=Windows NT 10.0.14393 x86_64)

# %% [markdown]
# ## Time to walk the elements of the "Bertha" mother element
# ### This has turned out to be a big thing.  It needs to be tackled for sucessful parsing of nathan and tom elements.
# ### We do not look for indepentent trees for verified pointers.  We exploit the fact that the nathans and toms are paired by the nature of the verified pointer
# ### If I have a nathan and I walk a portion of the tree through, the mother element to get to tom, then I should be able to do the same thing for other elements with the same name as the parent element of nathan that are decendants of bertha.

# %%
% run contactsScraper.py
# Out:
# Done
# Done
# KEYS
# Done
# Done
# RECORDS COLLECTED
# DATAFRAMES READY
# RECORD OUTPUT READY
# CONTACT CHECKER READY

# %%
import numpy as np
import pandas as pd

# %%
orgsForToday = ['National Association for Multi-Ethnicity In Communications (NAMIC)',
                'Association for Women in Science',
                'Brain Injury Association of America',
                'American Society of Home Inspectors',
                'NAADAC, the Association for Addiction Professionals',
                'American Public Transportation Association',
                'Indiana Soybean Alliance',
                'Associated Builders and Contractors (ABC)',
                'National Association of Social Workers',
                'American Marketing Association (AMA)']

# %%
org  = orgsForToday[9]

vh = cc.MotherSetVerifier(org)
# Out:
# No Fred
# No Reggies
# No Fred
# No Fred
# No Fred
# No Fred

# %%
cc.VerificationHandler.orgRecords.orgSessionStatusCheck()
# Out:
# ['Wed Oct 18, 2017  15:58:39', '5.405', 's', 'Good']

# %%
pointers = vh.verifiedPointers

# %%
len(pointers)
# Out:
# 5

# %%
## Grandmother Finding Algorithm

gmElements = []
gmMatrix = []

for i in range(len(pointers)):
    igmElements = []
    for j in range(i):
        ## Check to see if the Any Mother element is a Big Momma or "Bertha" Element
        if pointers[i].get_mother_element() is pointers[j].get_mother_element():
            gm = pointers[i].get_mother_element()
        else:
            gm = pointers[i].common_parent(pointers[j])
        # Append Match to Grand Mother Matrix
        igmElements.append(gm)
        
        # Check to see if this is a new grand mother element,
        # if so append to the gmElements list of unique grandmother elements 
        if gm not in gmElements:
            gmElements.append(gm)
            
    # Append Matrix Row
    gmMatrix.append(igmElements)
    
grandMotherMatrix = np.matrix(gmMatrix)

# %%
## Check the number of grandmothers
len(gmElements)
# Out:
# 1

# %%
type(gmElements[0])
# Out:
# bs4.element.Tag

# %%
gm = gmElements[0]

# %%
a = pointers[0].get_mother_element()
b = pointers[1].get_mother_element()

# %%
a is b
# Out:
# False

# %%
b is gm
# Out:
# False

# %%
p0 = pointers[0]

# %%
p0.nathan.parent
# Out:
# <a href="mailto:afriedman@ama.org" style="font-size:1.17em;">Andy Friedman​</a>

# %%
p1 = pointers[1]

# %%
p0.nathan.parent.name
# Out:
# 'a'

# %%
print(gm.prettify())
# Out:
# <div aria-labelledby="ctl00_PlaceHolderMain_PageContent_label" class="ms-rtestate-field" id="ctl00_PlaceHolderMain_PageContent__ControlWrapper_RichHtmlField" style="display:inline">
#  <h2 class="ms-rteElement-H2">
#   Executive Officers
#   <br/>
#   <br/>
#  </h2>
#  <div>
#   Chief Executive Officer -
#   <a href="mailto:rklein@ama.org" style="font-size:1.17em;">
#    Russ Klein​​
#   </a>
#  </div>
#  <div>
#   <br/>
#  </div>
#  <div tom="0">
#   Chief Content Officer -
#   <a href="mailto:afriedman@ama.org" nathan="0" sib="nathan" style="font-size:1.17em;">
#    Andy Friedman​
#   </a>
#  </div>
#  <div>
#   <br/>
#  </div>
#  <div>
#   Chief Alliance Officer -
#   <a href="mailto:bgrobicki@ama.org" style="font-size:1.17em;">
#    Barbara Grobicki​​
#   </a>
#  </div>
#  <div>
#   <br/>
#  </div>
#  <div>
#   Chief Experience Officer -
#   <a href="mailto:jseverns@ama.org" style="font-size:1.17em;">
#    Jennifer Severns​​
#   </a>
#  </div>
#  <div>
#   <br/>
#  </div>
#  <div>
#   Chief Operations Officer -
#   <a href="mailto:jvanek@ama.org" style="font-size:1.17em;">
#    Jeremy Van Ek​​
#   </a>
#  </div>
#  <div>
#   <br/>
#  </div>
#  <h2 class="ms-rteElement-H2">
#   Directors
#   <br/>
#   <br/>
#  </h2>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <h3 class="ms-rteElement-H3">
#   <span>
#    Strategic Alliances &amp; Foundation Relations Director - Julie Schnidman
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#    HR Director - Kelly Scullin-Javier
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   Commercial Alliances Director - Andrew Nelmes
#  </h3>
#  <h3 class="ms-rteElement-H3">
#   Community Experience Director - Megan Backes
#   <br/>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#    Live Experience Director - Cher Doherty
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   ​Brand Experience &amp; Marketing Director - Adara Bowen
#   <br/>
#  </h3>
#  <h3 class="ms-rteElement-H3">
#  </h3>
#  <h3 class="ms-rteElement-H3">
#   <span>
#    Digital Content Director - Christopher Bartone
#   </span>
#  </h3>
#  <h3 class="ms-rteElement-H3">
#  </h3>
#  <h3 class="ms-rteElement-H3">
#   <span>
#    Omni Channel Academic Content Director - Matt Weingarden
#    <br/>
#   </span>
#   Director, Customer Experience &amp; Insights - Scott Stern
#  </h3>
#  <div>
#   <span>
#    <br/>
#   </span>
#  </div>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <br/>
#  </h3>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#   <hr/>
#   <h2 class="ms-rteElement-H2">
#    Department Contacts
#    <br/>
#    <br/>
#   </h2>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <div>
#  </div>
#  <h3 class="ms-rteElement-H3">
#   <span>
#    Accounting -
#    <a href="mailto:mpemberton@ama.org">
#     Michael Pemberton​
#    </a>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span style="line-height:1.1em;background-color:transparent;">
#    <span>
#     Customer Service -
#    </span>
#   </span>
#   <a href="mailto:kwilliams@ama.org" style="line-height:1.1em;background-color:transparent;">
#    <span>
#     Kim Williams
#    </span>
#   </a>
#   <br/>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#    <span>
#     Marketing -
#    </span>
#   </span>
#   <span>
#    <a href="mailto:%20abowen@ama.org">
#     Adara Bowen
#    </a>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <div>
#   <h3 class="ms-rteElement-H3">
#    <span>
#     <span>
#      Chapters, Councils, and Volunteers -
#     </span>
#    </span>
#    <a href="mailto:mbackes@ama.org">
#     <span>
#      Megan Backes
#     </span>
#    </a>
#   </h3>
#  </div>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#    Publications -
#   </span>
#   <span>
#    <a href="mailto:%20msoat@ama.org">
#     <span>
#      Mo
#     </span>
#     lly Soat​
#    </a>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#    Journals
#   </span>
#   <span>
#    <span>
#    </span>
#   </span>
#   <span>
#    <span>
#     -
#    </span>
#   </span>
#   <span>
#    <span>
#     <a href="mailto:mweingarden@ama.org">
#      Matt Weingarden​
#     </a>
#    </span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#   </span>
#  </h3>
#  <span>
#  </span>
#  <h3 class="ms-rteElement-H3">
#   <span>
#    ​​
#   </span>
#  </h3>
#  <div>
#   <h3 class="ms-rteElement-H3">
#    For membership inquiries, please email us at
#    <a href="mailto:info@ama.org" target="_blank">
#     info@ama.org​
#    </a>
#    or call (800) AMA-1150.
#   </h3>
#  </div>
#  <div>
#   <br/>
#  </div>
#  <div>
#   <br/>
#  </div>
#  <div>
#   ​
#  </div>
#  ​​​​​​​​​​​​
# </div>

# %%
len(list(gm.children))
# Out:
# 51

# %%
len(list(gm.descendants))
# Out:
# 83

# %% [markdown]
# #### 'find_all' passes the gm decendants test

# %%
gm.find_all('strong') ## These are not direct decendants, two levels down
# Out:
# [<strong>Kathryn Conley Wehrmann, PhD, MSW, LCSW</strong>,
#  <strong>Mildred (Mit) Joyner, MSW, LCSW, BCD</strong>,
#  <strong>Heather Bradley-Geary, MSW</strong>,
#  <strong>Patrick J. Johnson, LCSW </strong>]

# %%
gm.find_all('strong')[0].parent.parent is gm
# Out:
# True

# %%
p1.nathan.parent.name
# Out:
# 'h3'

# %%
gm.find_all('h2')
# Out:
# [<h2 class="h2_addpading" sib="-6"> President </h2>,
#  <h2 class="h2_addpading" sib="tom" tom="0"> Vice President </h2>,
#  <h2 class="h2_addpading" sib="7"> Secretary </h2>,
#  <h2 class="h2_addpading" sib="14"> Treasurer </h2>]

# %%
starts = gm.find_all(p1.nathan.parent.name)

# %%
starts  ## Good
# Out:
# [<a href="mailto:rklein@ama.org" style="font-size:1.17em;">Russ Klein​​</a>,
#  <a href="mailto:afriedman@ama.org" style="font-size:1.17em;">Andy Friedman​</a>,
#  <a href="mailto:bgrobicki@ama.org" style="font-size:1.17em;">Barbara Grobicki​​</a>,
#  <a href="mailto:jseverns@ama.org" style="font-size:1.17em;">Jennifer Severns​​</a>,
#  <a href="mailto:jvanek@ama.org" style="font-size:1.17em;">Jeremy Van Ek​​</a>,
#  <a href="mailto:mpemberton@ama.org">Michael Pemberton​</a>,
#  <a href="mailto:kwilliams@ama.org" style="line-height:1.1em;background-color:transparent;"><span>Kim Williams</span></a>,
#  <a href="mailto:%20abowen@ama.org">Adara Bowen</a>,
#  <a href="mailto:mbackes@ama.org"><span>Megan Backes</span></a>,
#  <a href="mailto:%20msoat@ama.org"><span>Mo</span>lly Soat​</a>,
#  <a href="mailto:mweingarden@ama.org">Matt Weingarden​</a>,
#  <a href="mailto:info@ama.org" target="_blank">info@ama.org​</a>]

# %%
starts[0].previous_sibling
# Out:
# 'Chief Executive Officer - '

# %%
## Tag tree with pattern from nathan to tom
def tag_nathans(pt):
    return parent_cycle_up(pt.get_mother_element(), pt.nathan.parent, 'nathan', 0)

def tag_toms(pt):
    return parent_cycle_up(pt.get_mother_element(), pt.tom.parent, 'tom', 0)

def parent_cycle_up(motherElement, element, atr, num):
    ## for the bertha case we stop at the element that is right befor the mother elemenet
    if element.parent is motherElement:
        element[atr] = num
        element['sib'] = atr
    else:
        element[atr] = num
        return(motherElement, element.parent, atr, num + 1)
    
def has_sib(tag):
    return 'sib' in tag.attrs

def has_tom(tag):
    return 'tom' in tag.attrs

def has_nathan(tag):
    return 'nathan' in tag.attrs

def is_tom_sib(tag):
    return 'sib' in tag.attrs and tag['sib'] == 'tom'

def is_tom_n(tag):
    return 'sib' in tag.attrs and tag['sib'] == 'tom'

def is_tom_shoulder(tag):
    return 'sib' in tag.attrs and tag['sib'] == 'tom'

def is_nathan_sib(tag):
    return 'sib' in tag.attrs and tag['sib'] == 'nathan'

def is_nathan_n(tag):
    return 'sib' in tag.attrs and tag['sib'] == 'nathan'

def is_nathan_shoulder(tag):
    return 'sib' in tag.attrs and 'nathan' in tag.attrs

def tag_sibs(pt):
    tomShoulder = pt.get_mother_element().find(is_tom_shoulder)
    sibNo = 0
    for posSib in tomShoulder.next_siblings:
        if posSib.name:  # Element has to have a name
            sibNo += 1
            posSib['sib'] = sibNo

    
    sibNo = 0
    for negSib in tomShoulder.previous_siblings:
        if negSib.name: # Element has to have a name
            sibNo -= 1
            negSib['sib'] = sibNo

def reset_tree(pt):
    ## Clear all tom, nathan and sib atributes
    gm = pt.get_mother_element()
    
    for tomTag in gm.find_all(has_tom):
        del tomTag['tom']    
    for nathanTag in gm.find_all(has_nathan):
        del nathanTag['nathan']    
    for sibTag in gm.find_all(has_sib):
        del sibTag['sib']

# %%
def get_tom(fnd, taggedPt):
    ## Step1: Iterate up the tree to the nathan shoulder element
   # try:
    fns = to_nathan_shoulder(fnd, taggedPt.nathan.parent)
   #except:
        #print('Caught Attribute here')
        #return 'Fail'
    
    ## Step2: Iterate accross to tom shoulder element
    nathanShoulder = taggedPt.get_mother_element().find(is_nathan_shoulder)
    offset = nathanShoulder['sib']
    
    if offset > 0:
        ## tom's shoulder is to the left
        fts = to_tom_shoulder_left(fns, nathanShoulder)
        
    elif offset < 0:
        ## tom shoulder is to the right
        fts = to_tom_shoulder_right(fns, nathanShoulder)
        
    else:
        print("Make me wanna holla, throw up both my hands. wtf")
        
    tomShoulder = taggedPt.get_mother_element().find(is_tom_shoulder)
    
    ## Step3: fts and tomShoulder are defined, down cycle to get the tom element
    if tomShoulder['tom'] == 0: ## This is the tom eclosing parent, send string
        return fts.string
    else:
        return parent_cycle_down(fts.children, tomShoulder.children, 'toms')
    
    
def to_nathan_shoulder(findTag, ptTag):
    if is_nathan_shoulder(ptTag):
        return findTag
    else:
        return to_nathan_shoulder(findTag.parent, ptTag.parent)

# Tom's shoulder is to the left of Nathan's
def to_tom_shoulder_left(findTag, ptTag):
    # Don't test either the Find or pointer Tags if they are on stings
    if not ptTag.name:
        return to_tom_shoulder_left(findTag, ptTag.previous_sibling)
    if not findTag.name:
        return to_tom_shoulder_left(findTag.previous_sibling, ptTag)
    if is_tom_shoulder(ptTag):
        # Base Case: if a string is here just advance the findTag only
        return findTag
    else:
        # Recurse Case, keep stepping
        return to_tom_shoulder_left(findTag.previous_sibling, ptTag.previous_sibling)
    
# Tom's shoulder is to the right of Nathan's
def to_tom_shoulder_right(findTag, ptTag):
    if not ptTag.name:
        # If this is not a tag, advance to the next one
        return to_tom_shoulder_right(findTag, ptTag.next_sibling)
    if not findTag.name:
        # Same for the find Tag, if this is not a tag advance to the next one
        return to_tom_shoulder_right(findTag.next_sibling, ptTag)
    if is_tom_shoulder(ptTag):
        # Base Case, test ptTag Return find Tag
        return findTag
    else:
        # recurse case, advance both
        return to_tom_shoulder_right(findTag.next_sibling, ptTag.next_sibling)
    
def parent_cycle_down(fi, mi, atr):
    ## Loop accoss both found and mother iterators
    ## Precondition the 'atr' is an atribute of at least one elment in mi
    for f, s in zip(fi, mi):       
        ## look for attr
        print('foundTrunk: ' + f.name + str(f.attrs) + '   motherTrunk: ' + s.name + str(s.attrs))
        if atr in s.attrs:
            if s[atr] == 0:  ## Tag enclosing the pointer
                ## Return String inside, thats all!
                return f.string
            else:
                return parent_cycle_down(f.children, s.children, atr)

# %%
tag_nathans(p0)
tag_toms(p0)
tag_sibs(p0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-e499e59780e1> in <module>()
#       1 tag_nathans(p0)
#       2 tag_toms(p0)
# ----> 3 tag_sibs(p0)
#
# <ipython-input-115-f56247e6ff9d> in tag_sibs(pt)
#      45     tomShoulder = pt.get_mother_element().find(is_tom_shoulder)
#      46     sibNo = 0
# ---> 47     for posSib in tomShoulder.next_siblings:
#      48         if posSib.name:  # Element has to have a name
#      49             sibNo += 1
#
# AttributeError: 'NoneType' object has no attribute 'next_siblings'

# %%
get_tom(starts[0], p0)

# %%
reset_tree(p0)

# %%
## Seach Children By Attribute
p1.tom.parent.attrs
# Out:
# {'class': ['h2_addpading'], 'sib': 'tom', 'tom': 0}

# %%
ts=p1.get_mother_element().find(is_tom_shoulder)

# %%
# Tagging the siblings
## Start with the tom shoulder
gm.find(is_tom_shoulder)
## iterate positive to the right

## iterate negative to the left

# %%
gm.find(is_tom_shoulder)
# Out:
# <h2 class="h2_addpading" sib="tom" tom="0"> Vice President </h2>

# %%
len(list(ts.next_siblings))
# Out:
# 38

# %%
len(list(ts.previous_siblings))
# Out:
# 12

# %%
ns = gm.find(is_nathan_shoulder)

# %%
type(type(ts))
# Out:
# type

# %%
ts.name
# Out:
# 'h2'

# %%
ts.string
# Out:
# ' Vice President '

# %%
ts.string.name == None
# Out:
# True

# %%
type(ns['sib'])
# Out:
# int

# %%
gm.find_all(has_nathan)
# Out:
# []

# %%
mothers = pointers

# %% [markdown]
# ## Long story short bring it all together

# %%
for mother in mothers:
    # For each verified pointer tag your nathans, toms and sibs
    tag_nathans(mother)
    tag_toms(mother)
    tag_sibs(mother)
    
    # Collect Results
    tomsFromMother = [get_tom(start, mother) for start in starts]
    nathansFromMother = [start.string for start in starts]

    # Reset the tree
    reset_tree(mother)

# %%
nathansFromMother
# Out:
# ['       Our success lies with our team of highly experienced professionals.     ',
#  'Eglon E. Simons',
#  'James C. Jones',
#  'Sandra Girado',
#  'S. Monique Wells',
#  'Susan Waldman',
#  'Darryl Jackson',
#  'Brandon D. Hewlett',
#  "Davana O'Brien"]

# %%
type(tomsFromMother[0])
# Out:
# NoneType
