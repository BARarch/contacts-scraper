# %%
# %run contactsScraper.py
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=829039132881-tm658s48p30jafdjcsdgtlm08h6b06ak.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fspreadsheets&access_type=offline&response_type=code
#
# If your browser is on a different machine then exit and re-run this
# application with the command-line parameter
#
#   --noauth_local_webserver
#
# Authentication successful.
# Storing credentials to C:\Users\Anthony\scripts\Contacts-Scraper\.credentials\sheets.googleapis.Scraper-X.json
# Done
# Done
# KEYS
# Done
# Done
# RECORDS COLLECTED
# DATAFRAMES READY

# %%
groupName1 = 'ASIS International'
groupName2 = 'United States Golf Association'
groupName3 = 'American Massage Therapy Association (AMTA) - HQ'
groupName4 = 'American Association of Law Libraries'
groupName5 = 'National League for Nursing'

# %%
groups = [groupName1, groupName2, groupName3, groupName4, groupName5]

# %%
groups
# Out:
# ['ASIS International',
#  'United States Golf Association',
#  'American Massage Therapy Association (AMTA) - HQ',
#  'American Association of Law Libraries',
#  'National League for Nursing']

# %%
orgRecords
# Out:
# [{'Directory link': 'https://www.hfma.org/contact/',
#   'Link 2': '',
#   'Link 3': '',
#   'Link 4': '',
#   'Organization': 'Healthcare Financial Management Association'},
#  {'Directory link': 'https://www.nraringoffreedom.com/meet-the-staff',
#   'Link 2': '',
#   'Link 3': '',
#   'Link 4': '',
#   'Organization': 'The National Rifle Association (NRA)'},
#  {'Directory link': 'https://www.aap.org/en-us/Pages/Chapter-Executive-Director-Contact-List-and-Websites.aspx',
#   'Link 2': '',
#   'Link 3': '',
#   'Link 4': '',
#   'Organization': 'American Academy of Pediatrics (AAP)'},
#  {'Directory link': 'http://www.usga.org/about/our-leadership.html',
#   'Link 2': '',
#   'Link 3': '',
#   'Link 4': '',
#   'Organization': 'United States Golf Association'},
#  {'Directory link': 'http://www.api.org/about/leadership-team',
#   'Link 2': '',
#   'Link 3': '',
#   'Link 4': '',
#   'Organization': 'American Petroleum Institute'},
# ...

# %%
a = dr[dr['Organization'] == groupName1]['Directory link']

# %%
a.tolist()[0]
# Out:
# 'https://www.asisonline.org/About-ASIS/Who-We-Are/Pages/default.aspx'

# %%
from selenium import webdriver

path_to_chromedriver = '/Users/Anthony/scripts/Contacts-Scraper/Drivers/chromedriver' # change path as needed
browser = webdriver.Chrome(path_to_chromedriver)

# %%
groupSources = {}
for groupName in groups:
    browser.get(dr[dr['Organization'] == groupName]['Directory link'].tolist()[0])
    groupSources[groupName] = browser.page_source

# %%
groupSources['National League for Nursing']
# Out:
# '<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml"><head id="Head1"><style type="text/css">@charset "UTF-8";[ng\\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide{display:none !important;}ng\\:form{display:block;}.ng-animate-block-transitions{transition:0s all!important;-webkit-transition:0s all!important;}.ng-hide-add-active,.ng-hide-remove{display:block!important;}</style><meta http-equiv="content-type" content="text/html; charset=utf-8" /><link rel="shortcut icon" href="/favicon.ico" /><meta name="viewport" content="width=device-width, initial-scale=1.0" />\n\t\t<script type="text/javascript" src="http://w.sharethis.com/button/p.js" async=""></script><script type="text/javascript" id="async-buttons" src="http://w.sharethis.com/button/async-buttons.js"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script src="//ajax.googleapis.com/ajax/libs/angularjs/1.2.27/angular.min.js"></script>\n\t\t<script src="//cdnjs.c
# ...

# %%
url = 'https://www.flightradar24.com/data/airports'
browser.get(url)

# %%
browser.page_source
# Out:
# '<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="en"><head><style type="text/css">@charset "UTF-8";[ng\\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style><meta http-equiv="X-UA-Compatible" content="IE=Edge" /><meta charset="utf-8" /><meta name="keywords" content="flightradar, fr24, flight, tracker, database, airlines" /><meta name="description" content="Flightradar24 is the best live flight tracker that shows air traffic in real time. Best coverage and cool features!" /><meta name="author" content="Flightradar24" /><meta name="google-site-verification" content="y8qh4psN7mOCRiUHIBn_CkSpvApAiV8Pl9KrN65wHKI" />  <meta name="apple-itunes-app" content="app-id=382233851" /><meta name="google-play-app" content="app-id=com.flightradar24free" /><meta name="twitter:card" content="app" /><meta name="twitter
# ...

# %%
url = 'https://pythonprogramming.net/parsememcparseface/'
browser.get(url)

# %%
from bs4 import BeautifulSoup
