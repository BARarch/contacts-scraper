# %%
import scraperModelGS as smgs

# %%
get_credentials = smgs.modelInit()

# %%
def getContacts():
    """Google Sheets API Code.
    Pulls urls for all NFL Team RSS Feeds
    https://docs.google.com/spreadsheets/d/1p1LNyQhNhDBNEOkYQPV9xcNRe60WDlmnuiPp78hxkIs/
    """
    credentials = get_credentials()
    http = credentials.authorize(smgs.httplib2.Http())
    discoveryUrl = ('https://sheets.googleapis.com/$discovery/rest?'
                    'version=v4')
    service = smgs.discovery.build('sheets', 'v4', http=http,
                              discoveryServiceUrl=discoveryUrl)

    #specify sheetID and range
    spreadsheetId = '1p1LNyQhNhDBNEOkYQPV9xcNRe60WDlmnuiPp78hxkIs'
    rangeName = 'Contacts!A2:N'
    result = service.spreadsheets().values().get(
        spreadsheetId=spreadsheetId, range=rangeName).execute()
    values = result.get('values', [])

    if not values:
        print('No data found.')
    else:
        print('Done')

    return values

# %%
def getAgencyDir():
    """Google Sheets API Code.
    Pulls urls for all NFL Team RSS Feeds
    https://docs.google.com/spreadsheets/d/1p1LNyQhNhDBNEOkYQPV9xcNRe60WDlmnuiPp78hxkIs/
    """
    credentials = get_credentials()
    http = credentials.authorize(smgs.httplib2.Http())
    discoveryUrl = ('https://sheets.googleapis.com/$discovery/rest?'
                    'version=v4')
    service = smgs.discovery.build('sheets', 'v4', http=http,
                              discoveryServiceUrl=discoveryUrl)

    #specify sheetID and range
    spreadsheetId = '1p1LNyQhNhDBNEOkYQPV9xcNRe60WDlmnuiPp78hxkIs'
    rangeName = 'Org Leadership Websites!A2:B'
    result = service.spreadsheets().values().get(
        spreadsheetId=spreadsheetId, range=rangeName).execute()
    values = result.get('values', [])

    if not values:
        print('No data found.')
    else:
        print('Done')

    return values

# %%
getContacts()
# Out:
# Done
# [['0010B00001qK6Dg',
#   "Alabama Cattleman's Association",
#   '0030B000021g4Uj',
#   'Jessica',
#   'Kennedy',
#   'Membership & Producer Contact Coordinator',
#   'jkennedy@bamabeef.org',
#   '201 South Bainbridge Street',
#   'Montgomery',
#   'AL',
#   '36104'],
#  ['0010B00001qK6Dg',
#   "Alabama Cattleman's Association",
#   '0030B000021g4Uy',
#   'Cynthia',
#   'Dondrea',
#   'Director of Accounting',
#   'cdondrea@bamabeef.org',
#   '201 South Bainbridge Street',
#   'Montgomery',
#   'AL',
#   '36104'],
#  ['0010B00001qK6Dg',
#   "Alabama Cattleman's Association",
#   '0030B000021g4U5',
#   'Erin',
#   'Beasley',
#   'Assistant Executive Vice President',
#   'ebeasley@bamabeef.org',
#   '201 South Bainbridge Street',
#   'Montgomery',
#   'AL',
#   '36104'],
#  ['0010B00001qK6Dg',
#   "Alabama Cattleman's Association",
#   '0030B000021g4Tb',
#   'Billy',
#   'Powell',
#   'Executive Vice President',
#   'bpowell@bamabeef.org',
#   '201 South Bainbridge Street',
#   'Montgomery',
#   'AL',
#   '36104'],
#  ['0010B00001qK6Dg',
#   "Alabama Cattleman's Association",
#   '',
#   'KIM ',
#   'MCBRAYER',
#   'Office Manager & Event Coordinator',
#   'kmcbrayer@bamabeef.org ',
#   '202 South Bainbridge Street',
#   'Montgomery',
#   'AL',
#   '36104'],
#  ['001U000000NLm57',
#   'The Ohio Society of CPAs',
#   '0030B0000249cC5',
#   'Joshua',
#   'Goldman',
#   'VP, Learning',
#   'jgoldman@ohiocpa.com',
#   '535 Metro Place South',
#   'Dublin',
#   'OH',
#   '43017-7810',
#   '',
#   '(614) 764-2727'],
#  ['001U000000NLm57',
#   'The Ohio Society of CPAs',
#   '003U000001qXIKJ',
#   'Denise',
#   'Ison-Miller',
#   'Director, Member Relationships',
#   'dmiller@ohiocpa.com',
#   '535 Metro Place South',
#   'Dublin',
#   'OH',
#   '43017-7810',
#   '',
#   '(614) 764-2727'],
#  ['001U000000NLm57',
#   'The Ohio Society of CPAs',
#   '003U000001qXIKd',
#   'Laura',
#   'Hay',
#   'Executive Vice President',
#   'lhay@ohio-cpa.com',
#   '535 Metro Place South',
#   'Dublin',
#   'OH',
#   '43017-7810',
#   '',
#   '(614) 764-2727'],
#  ['001U000000NLm57',
#   'The Ohio Society of CPAs',
#   '003U000001qXIJz',
#   'Tiffany',
#   'Crosby',
#   'Senior Manager, Learning',
#   'tcrosby@ohiocpa.com',
#   '535 Metro Place South',
#   'Dublin',
#   'OH',
#   '43017-7810',
#   '',
#   '(614) 764-2727'],
#  ['001U000000NLm57',
#   'The Ohio Society of CPAs',
#   '003U000000RB1JS',
#   'Sandra',
#   'Spieker',
#   'Marketing Manager',
#   'sspieker@ohio-cpa.com',
#   '535 Metro Place South',
#   'Dublin',
#   'OH',
#   '43017-7810',
#   '',
#   '(614) 764-2727'],
#  ['001U000000NLm57',
#   'The Ohio Society of CPAs',
#   '',
#   'Kyle',
#   'Bickhart',
#   'Chief Financial Officer',
#   'KBickhart@ohiocpa.com',
#   '536 Metro Place South',
#   'Dublin',
#   'OH',
#   '43017-7810',
#   '',
#   '(614) 764-2728'],
#  ['001U000000NLm57',
#   'The Ohio Society of CPAs',
#   '',
#   'Amy Bonacuse',
#   'Bonacuse',
#   'Vice President, Communications & Marketing',
#   'ABonacuse@ohiocpa.com',
#   '537 Metro Place South',
#   'Dublin',
#   'OH',
#   '43017-7810'],
#  ['001U000000NLm57',
#   'The Ohio Society of CPAs',
#   '',
#   'Suzanne ',
#   ' McCann',
#   'Director of Marketing',
#   'smccann@ohiocpa.com',
#   '538 Metro Place South',
#   'Dublin',
#   'OH',
#   '43017-7810'],
#  ['001U000000NLm57',
#   'The Ohio Society of CPAs',
#   '',
#   'Eleni ',
#   'Ragias',
#   'Senior Financial Analyst',
#   'ERagias@ohiocpa.com',
#   '539 Metro Place South',
#   'Dublin',
#   'OH',
#   '43017-7810'],
#  ['001U000000NLm57',
#   'The Ohio Society of CPAs',
#   '',
#   'Karen ',
#   'West',
#   'Executive Director',
#   'kwest@ohiocpa.com',
#   '540 Metro Place South',
#   'Dublin',
#   'OH',
#   '43017-7810'],
#  ['001U000000NLm57',
#   'The Ohio Society of CPAs',
#   '',
#   'Marlene ',
#   'Znidar',
#   'Executive Assistant',
#   'mznidar@ohiocpa.com',
#   '541 Metro Place South',
#   'Dublin',
#   'OH',
#   '43017-7810'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '0030B00001udCz2',
#   'Dominika',
#   'Skarka',
#   'Specialist, Organizatonal Affairs',
#   'dskarka@sccm.org',
#   '500 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056',
#   '',
#   '(847) 827-6869'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '003U000000LGeO0',
#   'Brian',
#   'Schramm',
#   'Director of Business Affairs',
#   'bschramm@sccm.org',
#   '500 Midway Dr',
#   'Mount Prospect',
#   'IL',
#   '60056-5611',
#   'United States',
#   '(847) 827-6869'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '0030B00001tu3Bz',
#   'Shelea',
#   'Pride',
#   'Customer Service Manager',
#   'spride@sccm.org',
#   '500 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056',
#   '',
#   '(847) 827-6869'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '0030B0000215Fp5',
#   'Melissa',
#   'Nielsen',
#   'Sr Manager of Communications',
#   'mnielsen@sccm.org',
#   '500 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056',
#   '',
#   '(847) 827-6869'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '003U000001rlIYG',
#   'Curt',
#   'Powell',
#   'Director of Marketing and Communications',
#   'cpowell@sccm.org',
#   '500 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056',
#   '',
#   '(847) 827-6869'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '003U000001BozET',
#   'Karen',
#   'Boman',
#   'Business Analyst',
#   'kboman@sccm.org',
#   '500 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '',
#   '',
#   '(847) 827-6869'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '003U0000019bd7N',
#   'Diana',
#   'Hughes CAE',
#   'Director of Organizational Affairs',
#   'dhughes@sccm.org',
#   '500 Midway Dr',
#   'Mount Prospect',
#   'IL',
#   '60056-5811',
#   '',
#   '(847) 287-6869'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '003U000001QTUiY',
#   'Pamela',
#   'Dallstream, CMP, CMM',
#   'Director of Education',
#   'pdallstream@sccm.org',
#   '500 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056',
#   '',
#   '(847) 827-6869'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '003U000000LFfc2',
#   'David',
#   'Martin',
#   'CEO/ Exec Vice Pres',
#   'dmartin@sccm.org',
#   '500 Midway Dr',
#   'Mt Prospect',
#   'IL',
#   '60056',
#   '',
#   '(847) 827-6869'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '003U0000015zliR',
#   'Laura',
#   'Lewis',
#   'Director of Technology',
#   'llewis@sccm.org',
#   '500 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056',
#   '',
#   '(847) 827-6869'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '003U0000015zliS',
#   'Patrick',
#   'Dati',
#   'Manager, Membership Recruitment and Retention',
#   'pdati@sccm.org',
#   '500 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056',
#   '',
#   '(847) 827-6869'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '',
#   'Gary ',
#   'Hohbein',
#   'Controller',
#   'ghohbein@sccm.org',
#   '501 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056',
#   '',
#   '(847) 827-6870'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '',
#   'Kenneth ',
#   'Klarich',
#   'Sales Manager',
#   'kklarich@sccm.org',
#   '502 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056',
#   '',
#   '(847) 827-6871'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '',
#   'Julie ',
#   'Oswald',
#   'Marketing Manager',
#   'joswald@sccm.org',
#   '503 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '',
#   'Lindsay ',
#   'Tintera',
#   'Membership Marketing Manager',
#   'ltintera@sccm.org',
#   '504 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '',
#   'Lindsay ',
#   'Kamowski',
#   'Marketing Specialist',
#   'lkamowski@sccm.org',
#   '505 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '',
#   'Christine ',
#   'Roerig',
#   'Marketing Specialist',
#   'croerig@sccm.org',
#   '506 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056'],
#  ['001U000000DBdTf',
#   'Society of Critical Care Medicine',
#   '',
#   'Vishakha ',
#   'Kumar',
#   'Senior Research Manager',
#   'vkumar@sccm.org',
#   '507 Midway Dr.',
#   'Mt. Prospect',
#   'IL',
#   '60056'],
#  ['001U000000DBcw2',
#   'National Minority Supplier Development Council, Inc',
#   '003U000000LFej0',
#   'Joset B.',
#   'Wright',
#   'President',
#   'joset.wright@nmsdc.org',
#   '1359 Broadway, Tenth Floor',
#   'New York',
#   'New York',
#   '10018',
#   '',
#   '(212) 944-2430'],
#  ['001U000000DBcw2',
#   'National Minority Supplier Development Council, Inc',
#   '003U000000LGTpk',
#   'Casilda',
#   'Del Valle',
#   'Vice President, Finance and Administration',
#   'casilda.delvalle@nmsdc.org',
#   '1359 Broadway Tenth Floor',
#   'New York',
#   'NY',
#   '10018',
#   '',
#   '(212) 944-2430'],
#  ['001U000000DBcw2',
#   'National Minority Supplier Development Council, Inc',
#   '003U0000015zlgU',
#   'Maureen',
#   'Simonette',
#   'Director, Development and Member Services',
#   'maureen.simonette@nmsdc.org',
#   '1359 Broadway Tenth Floor',
#   'New York',
#   'NY',
#   '10018',
#   '',
#   '(212) 944-2430'],
#  ['001U000000DBcw2',
#   'National Minority Supplier Development Council, Inc',
#   '',
#   'Christine ',
#   'Narine',
#   'Director, Finance',
#   'christine.narine@nmsdc.org',
#   '1360 Broadway Tenth Floor',
#   'New York',
#   'NY',
#   '10018',
#   '',
#   '(212) 944-2430'],
#  ['001U000000DBcw2',
#   'National Minority Supplier Development Council, Inc',
#   '',
#   'Naheed ',
#   'Elyasi',
#   'Director, Marketing and Communications',
#   'naheed.elyasi@nmsdc.org',
#   '1361 Broadway Tenth Floor',
#   'New York',
#   'NY',
#   '10018',
#   '',
#   '(212) 944-2430'],
#  ['001U0000004JkB1',
#   'Association of Fundraising Professionals (AFP)',
#   '003U000000T82ab',
#   'Todd',
#   'McLaughlin',
#   'Marketing Director',
#   'tmclaughlin@afpnet.org',
#   '4300 Wilson Boulevard, Suite 300',
#   'Arlington',
#   'VA',
#   '22203-4168',
#   'USA',
#   '(703) 519-8450'],
#  ['001U0000004JkB1',
#   'Association of Fundraising Professionals (AFP)',
#   '003U000000OqaoS',
#   'Michael',
#   'Nilsen',
#   'Communications &\nPublic Policy-WA',
#   'mnilsen@afpnet.org',
#   '8806 NE 127th Pl',
#   'Kirkland',
#   'WA',
#   '98034',
#   'United States',
#   '(703) 519-8451'],
#  ['001U0000004JkB1',
#   'Association of Fundraising Professionals (AFP)',
#   '0030B00001udru5',
#   'Baterdene',
#   'Yura',
#   'Finance & Accounting',
#   'byura@afpnet.org',
#   '4300 Wilson Blvd.',
#   'Arlington',
#   'VA',
#   '22203-4168',
#   'United States',
#   '703/519-8476'],
#  ['001U0000004JkB1',
#   'Association of Fundraising Professionals (AFP)',
#   '0030B00001udrvD',
#   'Heba',
#   'Mahmoud',
#   'Director, Chapter Services',
#   'hmahmoud@afpnet.org',
#   '4300 Wilson Blvd.',
#   'Arlington',
#   'VA',
#   '22203-4168',
#   'United States',
#   '(703) 519-8486'],
#  ['001U0000004JkB1',
#   'Association of Fundraising Professionals (AFP)',
#   '0030B00001udrwu',
#   'Taryn',
#   'Gold',
#   'Vice President, Chapter Administration',
#   'tgold@afpnet.org',
#   '4300 Wilson Blvd.',
#   'Arlington',
#   'VA',
#   '22203-4168',
#   'United States',
#   '(703) 684-0410'],
#  ['001U0000004JkB1',
#   'Association of Fundraising Professionals (AFP)',
#   '0030B00001udry2',
#   'Tiffany',
#   'Oglesby',
#   'Membership',
#   'toglesby@afpnet.org',
#   '4300 Wilson Blvd.',
#   'Arlington',
#   'VA',
#   '22203-4168',
#   'United States',
#   '(703) 519-8492'],
#  ['001U0000004JkB1',
#   'Association of Fundraising Professionals (AFP)',
#   '0030B00001udrxE',
#   'Terry',
#   'Rauh',
#   'COO',
#   'trauh@afpnet.org',
#   '4300 Wilson Blvd.',
#   'Arlington',
#   'VA',
#   '22203-4168',
#   'United States',
#   '(703) 519-8478'],
#  ['001U0000004JkB1',
#   'Association of Fundraising Professionals (AFP)',
#   '0030B00001udrwV',
#   'Sawanna',
#   'Foster',
#   'Membership',
#   'sfoster@afpnet.org',
#   '4300 Wilson Blvd.',
#   'Arlington',
#   'VA',
#   '22203-4168',
#   'United States',
#   '(703) 519-8471'],
#  ['001U0000004JkB1',
#   'Association of Fundraising Professionals (AFP)',
#   '0030B00001udrvr',
#   'Lori',
#   'Gusdorf',
#   'Membership/Chapter Services',
#   'lgusdorf@afpnet.org',
#   '4300 Wilson Blvd.',
#   'Arlington',
#   'VA',
#   '22203-4168',
#   'United States',
#   '(703) 519-8449'],
#  ['001U0000004JkB1',
#   'Association of Fundraising Professionals (AFP)',
#   '',
#   'Demond ',
#   'McWilliams',
#   'McWilliams',
#   'dmcwilliams@afpnet.org',
#   '4300 Wilson Blvd, Suite 300',
#   'Arlington',
#   'Virginia',
#   '22203',
#   'United States'],
#  ['001U0000004JkB1',
#   'Association of Fundraising Professionals (AFP)',
#   '',
#   'Haben',
#   'Kubrom',
#   'Accounting',
#   'hkubrom@afpnet.org',
#   '4300 Wilson Blvd, Suite 300',
#   'Arlington',
#   'Virginia',
#   '22203',
#   'United States'],
#  ['001U000000LXXir',
#   'Alumni Association of the University of Michigan',
#   '003U000000PI2Yg',
#   'Jerry',
#   'Sigler',
#   'CFO',
#   'jsigler@umich.edu',
#   '200 Fletcher Street',
#   'Ann Arbor',
#   'mi',
#   '48109',
#   '',
#   '(734) 763-5055'],
#  ['001U000000LXXir',
#   'Alumni Association of the University of Michigan',
#   '003U000000PHxxc',
#   'Steve',
#   'Grafton',
#   'President',
#   'sgrafton@umich.edu',
#   '200 Fletcher Street',
#   'Ann Arbor',
#   'mi',
#   '48109',
#   '',
#   '(734) 764-0384'],
#  ['001U000000LXXir',
#   'Alumni Association of the University of Michigan',
#   '003U000000PHxsy',
#   'Denise',
#   'Ilitch',
#   'Regent UofM',
#   'denise@ambassadormag.com',
#   '200 Fletcher Street',
#   'Ann Arbor',
#   'mi',
#   '48109',
#   '',
#   '(734) 764-0384'],
#  ['001U000000LXXir',
#   'Alumni Association of the University of Michigan',
#   '',
#   'ANGILA ',
#   'CHAPMAN',
#   'Executive Director of Business Operations',
#   'simpsona@umich.edu',
#   '200 Fletcher Street',
#   'Ann Arbor',
#   'mi',
#   '48109',
#   '',
#   '734.615.3126'],
#  ['001U000000LXXir',
#   'Alumni Association of the University of Michigan',
#   '',
#   'ANNE ',
#   'FEIGHAN',
#   'Vice President of Marketing',
#   'afeighan@umich.edu',
#   '200 Fletcher Street',
#   'Ann Arbor',
#   'mi',
#   '48109',
#   '',
#   ' 734.763.9743'],
#  ['001U0000007BaJP',
#   'Emergency Nurses Association',
#   '003U000001iFdBq',
#   'Earl',
#   'Austria',
#   'IT Manager',
#   '',
#   '915 Lee St.',
#   'Des Plaines',
#   'IL',
#   '60016-6569',
#   '60016-6569',
#   '(847) 460-4095'],
#  ['001U0000007BaJP',
#   'Emergency Nurses Association',
#   '003U000000OqakI',
#   'Maureen',
#   'Howard',
#   'Director, Member and Course Services',
#   'mhoward@ena.org',
#   '915 Lee St',
#   'Des Plaines',
#   'IL',
#   '60016-6569',
#   'United States',
#   '(847) 460-4095'],
#  ['001U0000007BaJP',
#   'Emergency Nurses Association',
#   '0030B00001wEDO2',
#   'Kelsey',
#   'Portuese',
#   'Component Relations Coordinator',
#   'kelsey.portuese@ena.org',
#   '915 Lee St.',
#   'Des Plaines',
#   'IL',
#   '60016-6569',
#   '60016-6569',
#   '(847) 460-4095'],
#  ['001U0000007BaJP',
#   'Emergency Nurses Association',
#   '0030B00001yyK7k',
#   'Lindsay',
#   'Paxton',
#   'Member Services Supervisor',
#   'lindsay.paxton@ena.org',
#   '915 Lee St.',
#   'Des Plaines',
#   'IL',
#   '60016-6569',
#   '60016-6569',
#   '(847) 460-4095'],
#  ['001U0000007BaJP',
#   'Emergency Nurses Association',
#   '0030B00001yyK6v',
#   'Kari',
#   'Zick',
#   'Manager, ENA Component Relations',
#   'kari.zick@ena.org',
#   '915 Lee St.',
#   'Des Plaines',
#   'IL',
#   '60016-6569',
#   '60016-6569',
#   '(847) 460-4092'],
#  ['001U0000007BaJP',
#   'Emergency Nurses Association',
#   '003U000001kDGCg',
#   'Bridget',
#   'Krause',
#   'Director, Member Relations',
#   'bridget.krause@ena.org',
#   '915 Lee St.',
#   'Des Plaines',
#   'IL',
#   '60016-6569',
#   '60016-6569',
#   '(847) 460-4095'],
#  ['001U0000007BaJP',
#   'Emergency Nurses Association',
#   '003U000001kCKGD',
#   'Evelyn',
#   'Nunez',
#   'AR Manager',
#   'evelyn.nunez@ena.org',
#   '915 Lee St.',
#   'Des Plaines',
#   'IL',
#   '60016-6569',
#   '60016-6569',
#   '(847) 460-4050'],
#  ['001U0000007BaJP',
#   'Emergency Nurses Association',
#   '003U000001QTORc',
#   'Bridget',
#   'Walsh, PHR',
#   'Chief Talent Officer',
#   'bridget.walsh@ena.org',
#   '915 Lee St.',
#   'Des Plaines',
#   'IL',
#   '60016-6569',
#   '60016-6569',
#   '(847) 460-4095'],
#  ['001U0000007BaJP',
#   'Emergency Nurses Association',
#   '003U000001QTOQU',
#   'Josie',
#   'Howard- Ruben, PhD, APN-CNS',
#   'Chief Nursing Officer',
#   'josie.howard-ruben@ena.org',
#   '915 Lee St.',
#   'Des Plaines',
#   'IL',
#   '60016-6569',
#   '60016-6569',
#   '(847) 460-4095'],
#  ['001U0000007BaJP',
#   'Emergency Nurses Association',
#   '003U000001suPM7',
#   'Cindy',
#   'Meehan',
#   'Chief Community Engagement Officer',
#   'cindy.meehan@ena.org',
#   '915 Lee St.',
#   'Des Plaines',
#   'IL',
#   '60016-6569',
#   '60016-6569',
#   '(847) 460-4008'],
#  ['001U000000Lad85',
#   'American Association of University Women (AAUW)',
#   '0030B000020ZPP2',
#   'Tom',
#   'Chappell',
#   'VP Finance',
#   'chappellt@aauw.org',
#   '1111 16th St NW',
#   'Washington',
#   'DC',
#   '20036-4873',
#   'United States',
#   '(202) 785-7700'],
#  ['001U000000Lad85',
#   'American Association of University Women (AAUW)',
#   '003U000000QVUsg',
#   'Mike',
#   'Gellman',
#   'Chief Financial Officer',
#   'gellmanm@aauw.org',
#   '1111 16th St NW',
#   'Washington',
#   'DC',
#   '20036-4809',
#   'United States',
#   '+1.202.785.7700'],
#  ['001U000000Lad85',
#   'American Association of University Women (AAUW)',
#   '0030B00001udBfz',
#   'Angela',
#   'Cooper',
#   'Senior Member Relations Manager',
#   'coopera@aauw.org',
#   '1111 16th St NW',
#   'Washington',
#   'DC',
#   '20036-4873',
#   'United States',
#   '(202) 463-7169'],
#  ['001U000000Lad85',
#   'American Association of University Women (AAUW)',
#   '003U000001naqMA',
#   'Claudia',
#   'Richards',
#   'Senior Branch Relations Manager',
#   'richardsc@aauw.org',
#   '1111 16th St NW',
#   'Washington',
#   'DC',
#   '20036-4873',
#   'United States',
#   '(202) 728-7614'],
#  ['001U000000Lad85',
#   'American Association of University Women (AAUW)',
#   '003U000000Oqaim',
#   'Christine',
#   'Jones',
#   'Vice President, Membership and Direct Marketing',
#   'jonesc@aauw.org',
#   '1111 16th St NW',
#   'Washington',
#   'DC',
#   '20036-4873',
#   'United States',
#   '(202) 463-7169'],
#  ['001U000000Lad85',
#   'American Association of University Women (AAUW)',
#   '003U000000QV9U3',
#   'Linda',
#   'Hallman',
#   'Chief Executive Officer',
#   'hallmanl@aauw.org',
#   '1111 16th St Nw',
#   'Washington',
#   'DC',
#   '20036',
#   '',
#   '(202) 463-7169'],
#  ['001U000000Lad85',
#   'American Association of University Women (AAUW)',
#   '003U000000QV9U4',
#   'Fong-Ching',
#   'Cheng',
#   'Vice President, Information Technology',
#   'fongchingc@aauw.org',
#   '1111 16th St Nw',
#   'Washington',
#   'DC',
#   '20036',
#   '',
#   '(202) 463-7169'],
#  ['001U000000Lad85',
#   'American Association of University Women (AAUW)',
#   '',
#   'Cordy ',
#   'Galligan',
#   'Vice President, Marketing and Communications',
#   'galliganc@aauw.org',
#   '1111 16th St Nw',
#   'Washington',
#   'DC',
#   '20036',
#   '',
#   '(202) 463-7169'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '003U000000OqayV',
#   'Artesha',
#   'Moore',
#   ' \nVice President, Membership, Education & Technology',
#   'amoore@apic.org',
#   '1275 K St. NW Tenth Floor',
#   'Washington',
#   'DC',
#   '20005',
#   'United States',
#   '(202) 454-2631'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '003U000000REpko',
#   'Elizabeth',
#   'Rose',
#   'Sr. IT Mgr, iMIS Administration',
#   'erose@apic.org',
#   '',
#   'Washington',
#   'DC',
#   '',
#   'United States',
#   '(202) 454-2634'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '003U00000161k9W',
#   'George',
#   'Margula CPA, MBA',
#   'Chief Financial Officer',
#   'gmargula@apic.org',
#   '1275 K St. NW Tenth Floor',
#   'Washington',
#   'DC',
#   '20005',
#   '',
#   '(202) 454-2607'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '003U00000161k9X',
#   'Katrina',
#   'Crist MBA',
#   'Chief Executive Officer',
#   'kcrist@apic.org',
#   '1275 K St. NW Tenth Floor',
#   'Washington',
#   'DC',
#   '20005',
#   '',
#   '(202) 454-2601'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '0030B00001zys8m',
#   'Lisa',
#   'Tomlinson',
#   'Vice President, Government Affairs and Practice Guidance',
#   'ltomlinson@apic.org',
#   '1275 K St. NW Tenth Floor',
#   'Washington',
#   'DC',
#   '20005',
#   'United States',
#   '(202) 454-2631'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '003U000001QSnTM',
#   'Barbara',
#   'Long',
#   'Sr. Director, Governance and Executive Affairs',
#   'blong@apic.org',
#   '1275 K St. NW Tenth Floor',
#   'Washington',
#   'DC',
#   '20005',
#   'United States',
#   '(202) 454-2631'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '003U000001EvO1H',
#   'Andrew',
#   'Saunders',
#   'Director, IT',
#   'dsaunders@apic.org',
#   '',
#   '',
#   'DC',
#   '',
#   '',
#   '(202) 454-2631'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '003U000001YpDq9',
#   'Hannah',
#   'Andrews',
#   'Senior Manager, eLearning',
#   'handrews@apic.org',
#   '1275 K St. NW Tenth Floor',
#   'Washington',
#   'DC',
#   '20005',
#   'United States',
#   '(202) 454-2631'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '',
#   'Julie',
#   'Blechman',
#   'Manager, Communications',
#   ' \njblechman@apic.org',
#   '1275 K St. NW Tenth Floor',
#   'Washington',
#   'DC',
#   '20005',
#   'United States',
#   '(202) 454-2631'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '',
#   'Correen',
#   'Dingle',
#   'Senior Manager, Marketing',
#   ' \ncdingle@apic.org',
#   '1275 K St. NW Tenth Floor',
#   'Washington',
#   'DC',
#   '20005',
#   'United States',
#   '(202) 454-2631'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '',
#   ' Jatarious',
#   'Frazier',
#   ' Executive Assistant',
#   ' jfrazier@apic.org',
#   '1275 K St. NW Tenth Floor',
#   'Washington',
#   'DC',
#   '20005',
#   'United States',
#   '(202) 454-2631'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '',
#   'Carlos',
#   'Fulcher',
#   'Executive Vice President',
#   ' cfulcher@apic.org',
#   '1275 K St. NW Tenth Floor',
#   'Washington',
#   'DC',
#   '20005',
#   'United States',
#   '(202) 454-2631'],
#  ['001U000000Lad88',
#   'Association for Professionals in Infection Control and Epidemiology (APIC)',
#   '',
#   'Lynn',
#   'Schneider',
#   'Sr. Director, Human Resources',
#   ' lschneider@apic.org',
#   '1275 K St. NW Tenth Floor',
#   'Washington',
#   'DC',
#   '20005',
#   'United States',
#   '(202) 454-2631'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '0030B0000200QWr',
#   'Jody',
#   'Hoyos',
#   'Vice President Member Services & Operations',
#   'jhoyos@awhonn.org',
#   '2000 L St. NW Suite 740',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '(202) 261-2454'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '003U000000QVUzU',
#   'Marie',
#   'Butler',
#   'Accounting Manager',
#   'mbutler@awhonn.org',
#   '2000 L St NW Ste 740',
#   'Washington',
#   'DC',
#   '20036-4912',
#   'United States',
#   '+1.202.261.2440'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '003U000000Oqaj8',
#   'Tom',
#   'Quash',
#   'Vice Pres, Mktg & Business Devlmt',
#   'tquash@awhonn.org',
#   '2000 L St NW #740',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '(202) 261-2400'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '003U000001Z9l7G',
#   'Seth',
#   'McMillan',
#   'Web Services Manager',
#   'smcmillan@awhonn.org',
#   '2000 L St. NW Suite 740',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '(202) 261-2400'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '003U000001Z9l5y',
#   'Wendy',
#   'Sahli',
#   'Sr. Director of Information Technology',
#   'wssahli@yahoo.com',
#   '2000 L St. NW Suite 740',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '(202) 261-2400'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '0030B00001zyr3L',
#   'Susan',
#   'Hohenhaus',
#   'Vice President of Business Development',
#   'shohenhaus@awhonn.org',
#   '2000 L St. NW Suite 740',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '(202) 261-2400'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '0030B00001zyqzE',
#   'Lynn',
#   'Erdman',
#   'Chief Executive Officer',
#   'lerdman@awhonn.org',
#   '2000 L St. NW Suite 740',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '(202) 261-2400'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '0030B000021eF3G',
#   'Courtney',
#   'Duggan',
#   'Manager, Digital Marketing',
#   'cduggan@awhonn.org',
#   '2000 L St. NW Suite 740',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '(202) 261-2400'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '003U000000Oqaoh',
#   'Billie',
#   'Robinson',
#   'Director, Mtgs & Convs',
#   'brobinson@awhonn.org',
#   '2000 L St NW #740',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '(202) 261-2400'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '003U000000Oqaj7',
#   'Carol',
#   'Strickland, CAE',
#   'Chief Financial Officer',
#   'carols@awhonn.org',
#   '1800 M St NW Suite 740 South',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '+1.202.261.2400'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '003U0000019bd7F',
#   'Summer',
#   'Gonter',
#   'Database Administrator',
#   'sgonter@awhonn.org',
#   '2000 L St NW #740',
#   'Washington',
#   'DC',
#   '20036',
#   '',
#   '(202) 261-2400'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '003U000001QSvHr',
#   'Alan',
#   'Chewning',
#   'Manager, Leadership Services',
#   'achewning@awhonn.org',
#   '2000 L St. NW Suite 740',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '(202) 261-2400'],
#  ['001U000000Lad89',
#   "Association of Women's Health, Obstetric and Neonatal Nurses (AWHONN)",
#   '003U000001EvO1I',
#   'Julie',
#   'Berry',
#   'Associate Director, Industry Relations & Exhibits',
#   'jberry@awhonn.org',
#   '1800 M Street, NW, Suite 740 South',
#   'Washington',
#   'DC',
#   '20036',
#   '',
#   '(202) 261-2400'],
#  ['001U000000Lad8J',
#   'The American Society for Metabolic and Bariatric Surgery',
#   '0030B00001zyEW8',
#   'Kim',
#   'Carmichael',
#   'Financial Manager',
#   'kim@asmbs.org',
#   '100 SW 75th St #201',
#   'Gainesville',
#   'FL',
#   '32607',
#   'United States',
#   '(352) 331-4900'],
#  ['001U000000Lad8J',
#   'The American Society for Metabolic and Bariatric Surgery',
#   '0030B00001zyEWm',
#   'Leslie',
#   'Vinson',
#   'State Chapters Manager',
#   'leslie@asmbs.org',
#   '100 SW 75th St #201',
#   'Gainesville',
#   'FL',
#   '32607',
#   'United States',
#   '(352) 331-4900'],
#  ['001U000000Lad8J',
#   'The American Society for Metabolic and Bariatric Surgery',
#   '0030B00001zyEWI',
#   'James',
#   'Osterhout',
#   'Director of IT',
#   'james@asmbs.org',
#   '100 SW 75th St #201',
#   'Gainesville',
#   'FL',
#   '32607',
#   'United States',
#   '(352) 331-4900'],
#  ['001U000000Lad8J',
#   'The American Society for Metabolic and Bariatric Surgery',
#   '0030B00001zysLZ',
#   'Jennifer',
#   'Wynn',
#   'Director of Committee Affairs, Assistance to Executive Director',
#   'jennifer@asmbs.org',
#   '100 SW 75th St #201',
#   'Gainesville',
#   'FL',
#   '32607',
#   'United States',
#   '(352) 331-4900'],
#  ['001U000000Lad8J',
#   'The American Society for Metabolic and Bariatric Surgery',
#   '003U000000Oqajj',
#   'Kristie',
#   'Kaufman',
#   'Director Operations',
#   'kristie@asmbs.org',
#   '100 SW 75th St #201',
#   'Gainesville',
#   'FL',
#   '32607',
#   'United States',
#   '(352) 331-4900'],
#  ['001U000000Lad8J',
#   'The American Society for Metabolic and Bariatric Surgery',
#   '',
#   'Reba Liddy ',
#   'Hernandez',
#   'COMMUNICATIONS COORDINATOR',
#   'reba@asmbs.org',
#   '100 SW 75th St #201',
#   'Gainesville',
#   'FL',
#   '32607',
#   'United States',
#   '(352) 331-4900'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '003U000000REhMu',
#   'Tina',
#   'Budnitz',
#   'Chief Strategic Development Officer',
#   'tbudnitz@hospitalmedicine.org',
#   '1500 Spring Garden Suite 501',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '(949) 400-4453'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '003U000000REhNn',
#   'Ethan',
#   'Gray',
#   'Vice President of Membership & Marketing',
#   'egray@hospitalmedicine.org',
#   '1500 Spring Garden Suite 501',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '(267) 702-2636'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '003U000000RCR1g',
#   'Tara',
#   'Watson',
#   'Director of Finance',
#   'twatson@hospitalmedicine.org',
#   '1500 Spring Garden Street',
#   'Philadlephia',
#   'PA',
#   '19130',
#   'United States',
#   '+1.267.702.2607'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '003U000000RCR1h',
#   'Shawn',
#   'Sullivan',
#   'Manager of Digital Communications',
#   'ssullivan@hospitalmedicine.org',
#   '1500 Spring Garden St',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '+1.267.702.2615'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '003U000000RCR1i',
#   'Michelle',
#   'Kann',
#   'Director of Meetings',
#   'mkann@hospitalmedicine.org',
#   '1500 Spring Garden St.',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '+1.267.702.2652'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '003U000000RCR1k',
#   'Kimberly',
#   'Russell',
#   'Data Operations Manager',
#   'kdowd@hospitalmedicine.org',
#   '1500 Spring Garden St',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '(267) 702-2605'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '003U000000RCR1l',
#   'Jade',
#   'Myers',
#   'Manager, Meetings',
#   'jmyers@hospitalmedicine.org',
#   '1500 Spring Garden St.',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '+1.267.702.2655'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '003U000001Ze01D',
#   'Taylor',
#   'Griffith',
#   'Membership Engagement Manager',
#   'tgriffith@hospitalmedicine.org',
#   '1500 Spring Garden Suite 501',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '+1.267.702.2631'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '003U000001ZdzrD',
#   'Emily',
#   'Woods',
#   'Marketing Manager',
#   'emilyrwoods@gmail.com',
#   '1500 Spring Garden Suite 501',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '+1.267.702.2631'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '',
#   'Beth ',
#   'Hawley',
#   'Chief Operating Officer',
#   'bhawley@hospitalmedicine.org',
#   '1500 Spring Garden Suite 501',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '',
#   'Kristin ',
#   'Scott',
#   'Director, Business Development',
#   'kscott@hospitalmedicine.org',
#   '1500 Spring Garden Suite 501',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '267-702-2604'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '',
#   'Henry ',
#   'Niehe',
#   'Senior Accountant',
#   'hniehe@hospitalmedicine.org',
#   '1500 Spring Garden Suite 501',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '+1.267.702.2631'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '',
#   'Joi ',
#   'Seabrooks',
#   'Director of Human Resources',
#   'jseabrooks@hospitalmedicine.org',
#   '1500 Spring Garden Suite 501',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '+1.267.702.2631'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '',
#   'Lisa ',
#   'Chester',
#   'Project Manager, Member Engagement',
#   'lchester@hospitalmedicine.org',
#   '1500 Spring Garden Suite 501',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '+1.267.702.2631'],
#  ['001U000000LadAE',
#   'Society of Hospital Medicine',
#   '',
#   'Tommy ',
#   'George',
#   'Vice President, Information Technology',
#   'tgeorge@hospitalmedicine.org',
#   '1500 Spring Garden Suite 501',
#   'Philadelphia',
#   'PA',
#   '19130',
#   'United States',
#   '+1.267.702.2631'],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '003U000000Oqb0t',
#   'Mary',
#   'Ressler',
#   'Director, Components and Membership',
#   'mary.ressler@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   'United States',
#   '(713) 623-4362'],
#  [],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '0030B00001zY52r',
#   'Anika',
#   'Sayeed',
#   'Components Liaison',
#   'anika.sayeed@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   'United States',
#   '(713) 623-4362'],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '0030B00001udGPK',
#   'Joshua',
#   'Amos',
#   'Components Liaison',
#   'joshua.amos@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   'United States',
#   '(713) 623-4362'],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '0030B00001udDYg',
#   'Jaclyn',
#   'Lee',
#   ' Team Lead, Components',
#   'jlee@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   'United States',
#   '(713) 623-4362'],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '0030B00001wEO2L',
#   'John',
#   'Perry',
#   'COO',
#   'john.perry@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   'United States',
#   '(713) 623-4362'],
#  [],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '003U00000160z4P',
#   'Lindy',
#   'Daniels',
#   'Director, Information Systems',
#   'lindy.daniels@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   '',
#   '(713) 623-4362'],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '003U00000160z4Q',
#   'Tony',
#   'Keane, CAE',
#   'President and Chief Executive Officer',
#   'tony.keane@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   '',
#   '(713) 623-4362'],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '',
#   'Sheri ',
#   'Mitchell',
#   'Director, Human Resources',
#   'sheri.young@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   'United States',
#   '(713) 623-4362'],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '',
#   'Linda ',
#   'Pate ',
#   'Executive Assistant',
#   'linda.pate@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   'United States',
#   '(713) 623-4362'],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '',
#   'Holly ',
#   'Kendall',
#   'Vice President, Accounting',
#   'holly.kendall@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   'United States',
#   '(713) 623-4362'],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '',
#   'Jennifer ',
#   'Muesse',
#   'Director, Accounting',
#   'jennifer.muesse@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   'United States',
#   '(713) 623-4362'],
#  ['001U000000Lad8f',
#   'International Facility Management Association (IFMA)',
#   '',
#   'Elissa',
#   ' Krupala',
#   'Accounting Administrator',
#   'apinvoices@ifma.org',
#   '1 E. Greenway Plaza Suite 1100',
#   'Houston',
#   'TX',
#   '77046',
#   'United States',
#   '(713) 623-4362'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '0030B0000235Jys',
#   'Jason',
#   'Bradley',
#   'Governance & Affiliate Relations',
#   'jbradley@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '0030B0000249jYW',
#   'Keith',
#   'Greer',
#   'Foundation Director',
#   'kgreer@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '0030B0000249jWf',
#   'Lisa',
#   'DeTemple',
#   'VP of HR',
#   'ldetemple@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '0030B0000249jV8',
#   'Jake',
#   'Buehler',
#   'Chief Communications Officer',
#   'jbuehler@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '0030B0000249jVX',
#   'Craig',
#   'St. George',
#   'Director of Online Education',
#   'cstgeorge@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000001GB3wc',
#   'Myke',
#   'Kudlas',
#   'Associate Executive Director',
#   'mkudlas@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000000Oqalq',
#   'Ellen',
#   'Lipman',
#   'Director of Professional Development',
#   'elipman@asrt.org',
#   '15000 Central Ave SE',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000000Oqalv',
#   'John',
#   'Padilla',
#   'Director of Purchasing/Shipping and Receiving',
#   '',
#   '15000 Central Ave SE',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000001qUYqE',
#   'Christine',
#   'Pauley',
#   'Director of Meetings and Conferences',
#   'cpauley@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000000Oqalu',
#   'Salvatore',
#   'Martino',
#   'Chief Executive Officer',
#   'smartino@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000001QSdBQ',
#   'Janet',
#   'McEwen',
#   'Director of Corporate Relations',
#   'jmcewen@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000001QScxd',
#   'Peter',
#   'Conlin',
#   'Director of Chief Information Officer',
#   'pconlin@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000001QScgC',
#   'Laura',
#   'Niel, CAE',
#   'CFO',
#   'lniel@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000001QSdDm',
#   'John',
#   'Culbertson',
#   'Director of Research',
#   'jculbertson@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000001QScs3',
#   'Christine',
#   'Lung, CAE',
#   'Vice President of State Advocacy and Government Relations',
#   'clung@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000001QSZwG',
#   'Rebecca',
#   'Apodaca',
#   'Director of Professional Practice',
#   'bapodaca@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000001QSd85',
#   'Dana',
#   'Aragon, CAE',
#   '\nChief Governance Officer',
#   'daragon@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad8t',
#   'American Society of Radiologic Technologists (ASRT)',
#   '003U000001QSciV',
#   'Sandra',
#   'Hayden, MA, RT(T)',
#   'Chairman of the Board',
#   'shayden@asrt.org',
#   '15000 Central Ave. SE Suite A',
#   'Albuquerque',
#   'NM',
#   '87123-3909',
#   'United States',
#   '(505) 298-4500'],
#  ['001U000000Lad97',
#   'CFA Institute',
#   '003U000001pRpne',
#   'Lauren',
#   'McAdams',
#   'Manager, Society Relations',
#   'lauren.mcadams@cfainstitute.org',
#   '915 East High Street',
#   'Charlottesville',
#   'VA',
#   '22902',
#   'United States',
#   '(434) 951-5499'],
#  ['001U000000Lad97',
#   'CFA Institute',
#   '003U000001rozkj',
#   'Tina',
#   'Sapsara',
#   'Executive Director - Research Foundation',
#   'tina.sapsara@cfainstitute.org',
#   '915 East High Street',
#   'Charlottesville',
#   'VA',
#   '22902',
#   'United States',
#   '(434) 951-5556'],
#  ['001U000000Lad97',
#   'CFA Institute',
#   '0030B00001wosHQ',
#   'Randi',
#   'Tolber',
#   'Director of Society Relations',
#   'randi.tolber@cfainstitute.org',
#   '915 East High Street',
#   'Charlottesville',
#   'VA',
#   '22902',
#   'United States',
#   '(434) 951-5499'],
#  ['001U000000Lad97',
#   'CFA Institute',
#   '003U000001NCp08',
#   'Kevin',
#   'Greenwood',
#   'Director of Information Technology',
#   'kevin.greenwood@cfainstitute.org',
#   '915 East High Street',
#   'Charlottesville',
#   'VA',
#   '22902',
#   'United States',
#   '(434) 951-5499'],
#  ['001U000000Lad97',
#   'CFA Institute',
#   '003U00000161k7w',
#   'Elaine',
#   'Cheng',
#   'Chief Information Officer',
#   'elaine.cheng@cfainstitute.org',
#   '915 East High Street',
#   'Charlottesville',
#   'VA',
#   '22902',
#   '',
#   '(434) 951-5499'],
#  ['001U000000Lad97',
#   'CFA Institute',
#   '003U00000161k7z',
#   'Kurt',
#   'N. Schacht CFA, JD',
#   'Managing Director, Standards and Financial Market Integrity',
#   'kurt.schacht@cfainstitute.org',
#   '915 East High Street',
#   'Charlottesville',
#   'VA',
#   '22902',
#   '',
#   '(434) 951-5499'],
#  ['001U000000Lad97',
#   'CFA Institute',
#   '003U00000161k80',
#   'Timothy',
#   'G. McLaughlin CFA, CPA',
#   'Chief Administrative Officer and Chief Financial Officer',
#   'tim.mclaughlin@cfainstitute.org',
#   '915 East High Street',
#   'Charlottesville',
#   'VA',
#   '22902',
#   '',
#   '(434) 951-5499'],
#  ['001U000000Lad97',
#   'CFA Institute',
#   '',
#   'Frederic P. ',
#   'Lebel',
#   'Co-CEO and CIO',
#   'boardofgovernors@cfainstitute.org',
#   '915 East High Street',
#   'Charlottesville',
#   'VA',
#   '22902',
#   '',
#   '41 (22) 776 86 33'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '0030B0000221Sl1',
#   'Denise',
#   'Davenport',
#   'Chapter Relations & Governance Assistant',
#   'ddavenport@caionline.org',
#   '6402 Arlington Blvd. Suite 500',
#   'Falls Church',
#   'VA',
#   '22042',
#   '',
#   '(703) 970-9220'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '0030B0000249DDz',
#   'Sondra',
#   'Frank',
#   'Chapter Relations Manager',
#   'sfrank@caionline.org',
#   '6402 Arlington Blvd. Suite 500',
#   'Falls Church',
#   'VA',
#   '22042',
#   '',
#   '(703) 970-9220'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U00000161wiL',
#   'Bruce',
#   'Townsend',
#   'Chief Financial Officer',
#   'btownsend@caionline.org',
#   '6402 Arlington Blvd Ste 500',
#   'Falls Church',
#   'VA',
#   '22042-2343',
#   'United States',
#   '+1.703.970.9264'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U000000Oqanl',
#   'Ann-Marie',
#   'Johnson',
#   'Director of Education Operations and Credentialing',
#   'ajohnson@caionline.org',
#   '4600 Kenwood Dr',
#   'Woodbridge',
#   'VA',
#   '22193',
#   'United States',
#   '(703) 970-9220'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U000000Oqanm',
#   'Marc',
#   'Ingram',
#   'Senior Manager, Advertising and Exhibits',
#   'mingram@caionline.org',
#   '6402 Arlington Blvd # 500',
#   'Falls Church',
#   'VA',
#   '22042',
#   'United States',
#   '(703) 970-9220'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U000000Oqann',
#   'Crystal',
#   'Wallace',
#   'Vice President, Membership & Chapter Relations',
#   'cwallace@caionline.org',
#   '6402 Arlington Blvd # 500',
#   'Arlington',
#   'VA',
#   '22042',
#   'United States',
#   '(703) 970-9231'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U000001ZBpfO',
#   'Roseann',
#   'Brown',
#   'Director IT for the Tech Conference',
#   'rbrown@caionline.org',
#   '6402 Arlington Blvd #500',
#   'Falls Church',
#   'VA',
#   '22042',
#   '',
#   '(000) 000-0000'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U000001ZBpgg',
#   'Amy',
#   'Adler',
#   'Sr. Manager, Web Projects',
#   'aadler@caionline.org',
#   '6402 Arlington Blvd #500',
#   'Falls Church',
#   'VA',
#   '22042',
#   '',
#   '(000) 000-0000'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U000000OqakK',
#   'Anna',
#   'Ylijoki-Rosato',
#   'Manager, Chapter Support & Development',
#   'aylijoki-rosato@caionline.org',
#   '6402 Arlington Blvd., Suite 500',
#   'Falls Church',
#   'VA',
#   '22042',
#   'United States',
#   '(703) 970-9220'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '0030B00001zyrMZ',
#   'Karen',
#   'McMullen',
#   'Senior Director, Membership and Chapter Relations',
#   'kmcmullen@caionline.org',
#   '6402 Arlington Blvd. Suite 500',
#   'Falls Church',
#   'VA',
#   '22042',
#   '',
#   '(703) 970-9220'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U0000018shSn',
#   'Jennifer',
#   'Flynn',
#   'Director of Governance',
#   'jflynn@caionline.org',
#   '',
#   '',
#   'VA',
#   '',
#   '',
#   '(703) 970-9220'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U00000161kB0',
#   'Thomas',
#   'M. Skiba CAE',
#   'Chief Executive Officer',
#   'tskiba@caionline.org',
#   '6402 Arlington Blvd. Suite 500',
#   'Falls Church',
#   'VA',
#   '22042',
#   '',
#   '(703) 970-9220'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U000001DVVjd',
#   'Olympia',
#   'Carter',
#   'Sr. Education Coordinator',
#   'ocarter@caionline.org',
#   '6402 Arlington Blvd #500',
#   'Falls Church',
#   'VA',
#   '22042',
#   '',
#   '(000) 000-0000'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U000001DVVje',
#   'Lauren',
#   'Ebbin',
#   'Education Coordinator',
#   'lebbin@caionline.org',
#   '6402 Arlington Blvd #500',
#   'Falls Church',
#   'VA',
#   '22042',
#   '',
#   '(000) 000-0000'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U000001DVVjf',
#   'Shari',
#   'Lewis',
#   'Education Manager',
#   'slewis@caionline.org',
#   '6402 Arlington Blvd #500',
#   'Falls Church',
#   'VA',
#   '22042',
#   '',
#   '(000) 000-0000'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U000001QTNRS',
#   'Jacob',
#   'Gold, CAE',
#   'Director of Education Development',
#   'jgold@caionline.org',
#   '6402 Arlington Blvd. Suite 500',
#   'Falls Church',
#   'VA',
#   '22042',
#   '',
#   '(703) 970-9220'],
#  ['001U000000Lad99',
#   'Community Associations Institute (CAI)',
#   '003U000001EvO0k',
#   'David',
#   'Jennings',
#   'Vice President, Education',
#   'djennings@caionline.org',
#   '',
#   '',
#   'VA',
#   '',
#   '',
#   '(703) 970-9220'],
#  ['001U000000Lad9H',
#   'Council for Exceptional Children',
#   '003U000001nZ9p0',
#   'Sharon',
#   'Rodriguez',
#   'Senior Executive Assistant ',
#   'sharonr@cec.sped.org',
#   '2900 Crystal Dr #1000',
#   'Arlington',
#   'VA',
#   '22202-3557',
#   'United States',
#   '(888) 232-7733'],
#  ['001U000000Lad9H',
#   'Council for Exceptional Children',
#   '003U000001nZ9nl',
#   'Megan',
#   'Jones',
#   'Digital Learning Coordinator',
#   'meganj@cec.sped.org',
#   '2900 Crystal Dr #1000',
#   'Arlington',
#   'VA',
#   '22202-3557',
#   'United States',
#   '(888) 232-7733'],
#  ['001U000000Lad9H',
#   'Council for Exceptional Children',
#   '003U000001nZ9ol',
#   'Bryan',
#   'Reynolds',
#   'Database Manager',
#   'bryanr@cec.sped.org',
#   '2900 Crystal Dr #1000',
#   'Arlington',
#   'VA',
#   '22202-3557',
#   'United States',
#   '703-264-9480'],
#  ['001U000000Lad9H',
#   'Council for Exceptional Children',
#   '003U000001nZ9pt',
#   'Lorraine',
#   'Sobson',
#   'Manager, Professional Publications',
#   'lorrainees@cec.sped.org',
#   '2900 Crystal Dr #1000',
#   'Arlington',
#   'VA',
# ...
#   'kmcdowell@asse.org',
#   '1800 E. Oakton St.',
#   'Des Plaines',
#   'IL',
#   '60018-2187',
#   'United States',
#   '(847) 699-2929'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '003U000001rp4L5',
#   'Judy',
#   'Brennan',
#   'Chapter Specialist - Chapter Development',
#   'judy.brennan@pmi.org',
#   '14 Campus Blvd.',
#   'Newtown',
#   'PA',
#   '19073-3299',
#   '',
#   '(610) 356-4600'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '003U000000OqamC',
#   'Leslie',
#   'Higham',
#   'Accreditation Program Specialist',
#   '',
#   '14 Campus Blvd',
#   'Newtown Square',
#   'PA',
#   '19073-3299',
#   'United States',
#   '(610) 356-4600'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '003U000000OqamD',
#   'Louise',
#   'Games',
#   'Membership Specialist',
#   'louise.games@pmi.org',
#   '14 Campus Blvd',
#   'Newtown Square',
#   'PA',
#   '19073-3299',
#   'United States',
#   '(610) 356-4600'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '0030B00001yzE3D',
#   'Michael',
#   'Liddy',
#   'Global IT Relationship Manager',
#   'michael.liddy@pmi.org',
#   '14 Campus Blvd.',
#   'Newtown',
#   'PA',
#   '19073-3299',
#   '',
#   '(610) 356-4600'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '0030B00001zYTgV',
#   'Brantlee',
#   'Underhill',
#   'Director, Global Chapters',
#   'brantlee.underhill@pmi.org',
#   '14 Campus Blvd.',
#   'Newtown',
#   'PA',
#   '19073-3299',
#   '',
#   '(610) 356-4600'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '003U000001rlVNr',
#   'Kristin',
#   'Dunn',
#   'Research Specialist',
#   'kristindunn@gmail.com',
#   '14 Campus Blvd.',
#   'Newtown',
#   'PA',
#   '19073-3299',
#   '',
#   '(610) 356-4600'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '003U000001NCqP6',
#   'Thomas',
#   'Rossi',
#   'Manager, Enterprise Architecture',
#   'thomas.rossi@pmi.org',
#   '14 Campus Blvd.',
#   'Newtown',
#   'PA',
#   '19073-3299',
#   '',
#   '(610) 356-4600'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '003U000000QVLYw',
#   'John',
#   'Doyle',
#   'Vice President, Finance and Administration',
#   'john.doyle@pmi.org',
#   '14 Campus Blvd.',
#   'Newtown',
#   'PA',
#   '19073-3299',
#   '',
#   '(610) 356-4600'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '003U000001OfrTx',
#   'Bill',
#   'Scarborough',
#   'VP & General Council',
#   'bill.scarborough@pmi.org',
#   '14 Campus Blvd.',
#   'Newtown',
#   'PA',
#   '19073-3299',
#   '',
#   '(610) 356-4600'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '003U000001QTf6T',
#   'Jamie',
#   'Gray',
#   'Volunteer Services Specialist',
#   'jamielynn.gray@pmi.org',
#   '14 Campus Blvd.',
#   'Newtown',
#   'PA',
#   '19073-3299',
#   '',
#   '(610) 356-4600'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '003U000001QTf5f',
#   'Kristin',
#   'Hodgson',
#   'Manager, Chapter Development- Americas',
#   'kristin.hodgson@pmi.org',
#   '14 Campus Blvd.',
#   'Newtown',
#   'PA',
#   '19073-3299',
#   '',
#   '(610) 356-4600'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '003U000000IzGBp',
#   'Peter',
#   'Monkhouse PMP',
#   'Secretary and Treasurer',
#   '',
#   '14 Campus Boulevard',
#   'Newtown Square',
#   'PA',
#   '19073-3299',
#   'United States',
#   '(610) 356-4600 or (855) 746-4849'],
#  ['001U000000Cnu2u',
#   'Project Management Institute (PMI)',
#   '003U000000IzGBu',
#   'Mark',
#   'Langley CPA',
#   'President and Chief Executive Officer',
#   'mark.langley@pmi.org',
#   '14 Campus Blvd',
#   'Newtown Square',
#   'PA',
#   '19073-3299',
#   '',
#   '(610) 356-4600'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U0000018rvAD',
#   'Warren',
#   'R. DeVries',
#   'Treasurer',
#   '',
#   '1828 L St. NW Suite 810',
#   'Washington',
#   'DC',
#   '20036-5104',
#   '',
#   '(202) 785-3756'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U000001qUZUm',
#   'Timothy',
#   'Graves',
#   'Director, Technical Conferences & Events',
#   'gravest@asme.org',
#   '1828 L St. NW Suite 810',
#   'Washington',
#   'DC',
#   '20036-5104',
#   '',
#   '(202) 785-3756'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U000000T5Z4P',
#   'William',
#   'Berger',
#   'Managing Director',
#   'bergerw@asme.org',
#   '3 Park Ave Fl 23',
#   'New York',
#   'NY',
#   '10016',
#   '',
#   '(212) 591-7000'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U000000T5Z5M',
#   'David',
#   'Soukup',
#   'Managing Director',
#   'soukupd@asme.org',
#   '3 Park Ave Fl 23',
#   'New York',
#   'NY',
#   '10016',
#   '',
#   '(212) 591-7000'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U000000T5Z5N',
#   'David',
#   'Wizda',
#   'Managing Director',
#   'wizdad@asme.org',
#   '3 Park Ave Fl 23',
#   'New York',
#   'NY',
#   '10016',
#   '',
#   '(212) 591-7000'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U000000T5Z5O',
#   'Mark',
#   'Hseehan',
#   'Managing Director',
#   'sheehanm@asme.org',
#   '3 Park Ave Fl 23',
#   'New York',
#   'NY',
#   '10016',
#   '',
#   '(212) 591-7000'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U000000T5Z5P',
#   'Michael',
#   'Merker',
#   'Associate Executive Director',
#   'merkerm@asme.org',
#   '3 Park Ave Fl 23',
#   'New York',
#   'NY',
#   '10016',
#   '',
#   '(212) 591-7000'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U000000J0DLq',
#   'W',
#   'MARNER',
#   'Secretary & Treasurer',
#   'marnerw@asme.org',
#   '3 Park Ave Fl 23',
#   'New York',
#   'NY',
#   '10016',
#   '',
#   '(212) 591-7000'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '0030B00001zyaSZ',
#   'Elena',
#   'Gerstmann',
#   'Deputy Executive Operations',
#   'gerstmanne@asme.org',
#   '1828 L St. NW Suite 810',
#   'Washington',
#   'DC',
#   '20036-5104',
#   '',
#   '(202) 785-3756'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '0030B00001zyaT8',
#   'Allian',
#   'Pratt',
#   'Director, K12 Education, Diversity & Scholarships',
#   'pratta@asme.org',
#   '1828 L St. NW Suite 810',
#   'Washington',
#   'DC',
#   '20036-5104',
#   '',
#   '(202) 785-3756'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '0030B00001wlqqb',
#   'Luis',
#   'Rodriguez',
#   'Associate Executive Director Technical Services',
#   'rodriguezl@asme.org',
#   '1828 L St. NW Suite 810',
#   'Washington',
#   'DC',
#   '20036-5104',
#   '',
#   '(202) 785-3756'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U000001NCosV',
#   'John',
#   'Falcioni',
#   'Editorial Director',
#   'falcionij@asme.org',
#   '1828 L St. NW Suite 810',
#   'Washington',
#   'DC',
#   '20036-5104',
#   '',
#   '(202) 785-3756'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U000001NCoTj',
#   'Thomas',
#   'Loughlin',
#   'Executive Director & CEO',
#   'loughlint@asme.org',
#   '1828 L St. NW Suite 810',
#   'Washington',
#   'DC',
#   '20036-5104',
#   '',
#   '(202) 785-3756'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U000000J0DE6',
#   'June',
#   'Ling',
#   'Associate Executive Director',
#   'junel@asme.org',
#   '1828 L St. NW Suite 810',
#   'Washington',
#   'DC',
#   '20036-5104',
#   'United States',
#   '(202) 785-3756'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U000000J0DB7',
#   'Thomas',
#   'G.Loughlin CAE',
#   'Executive Director',
#   'loughlint@asme.org',
#   'Two Park Ave.',
#   'New York',
#   'NY',
#   '10016-5990',
#   'United States',
#   '(212) 591-7000'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U0000015zTWu',
#   'Raj',
#   'Manchanda',
#   'Director, Business Development - Manufacturing & Robotics',
#   'manchandar@asme.org',
#   'Two Park Ave.',
#   'New York',
#   'NY',
#   '10016-5990',
#   'United States',
#   '(212) 591-7789'],
#  ['001U000000DAGUz',
#   'American Society of Mechanical Engineers (ASME)',
#   '003U0000015zTWw',
#   'William',
#   'Garofalo',
#   'Associate Executive Director, Finance',
#   'garofalow@asme.org',
#   '1828 L St. NW Suite 810',
#   'Washington',
#   'DC',
#   '20036-5104',
#   'United States',
#   '(202) 785-3756'],
#  ['001U000000DAWO6',
#   'Lions Clubs International (LCI)',
#   '0030B0000249mww',
#   'Diane',
#   'Keller',
#   'Assistant',
#   'diane.keller@lionsclubs.org',
#   '300 West 22nd Street',
#   'Oak Brook',
#   'IL',
#   '60523-8842',
#   '',
#   '(630) 571-5466'],
#  ['001U000000DAWO6',
#   'Lions Clubs International (LCI)',
#   '003U000000J0IP8',
#   'Peter',
#   'Lynch',
#   'Chief Strategic Advisor',
#   'peter.lynch@lionsclubs.org',
#   '300 West 22nd Street',
#   'Oak Brook',
#   'IL',
#   '60523-8842',
#   '',
#   '(630) 571-5466'],
#  ['001U000000DAcqM',
#   'American Society for Microbiology',
#   '0030B000020Z9Qi',
#   'Jason',
#   'Rao',
#   'Membership Director',
#   'jrao@asmusa.org',
#   '1752 N St. NW',
#   'Washington',
#   'DC',
#   '20036',
#   '',
#   '(202) 737-3600'],
#  ['001U000000DAcqM',
#   'American Society for Microbiology',
#   '0030B0000249c8r',
#   'Maisha',
#   'Miles',
#   'Managing Director',
#   'mmiles@asmusa.org',
#   '1752 N St. NW',
#   'Washington',
#   'DC',
#   '20036',
#   '',
#   '(202) 737-3600'],
#  ['001U000000DAcqM',
#   'American Society for Microbiology',
#   '003U000000Oqaiv',
#   'James',
#   'Sliwa',
#   'Manager, Media Relations',
#   'jsliwa@asmusa.org',
#   '1752 N St NW',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '+1.202.942.9297'],
#  ['001U000000DAcqM',
#   'American Society for Microbiology',
#   '003U000001rlIl2',
#   'Jennifer',
#   'Tomb',
#   'Assistant Director, Meetings and Exhibits',
#   'jtomb@asmusa.org',
#   '1752 N St. NW',
#   'Washington',
#   'DC',
#   '20036',
#   '',
#   '(202) 737-3600'],
#  ['001U000000DAcqM',
#   'American Society for Microbiology',
#   '003U000001rnXTz',
#   'Chris',
#   'Decesaris',
#   'Director of Financial Operations',
#   'cdecesaris@asmusa.org',
#   '1752 N St. NW',
#   'Washington',
#   'DC',
#   '20036',
#   '',
#   '(202) 737-3600'],
#  ['001U000000DAcqM',
#   'American Society for Microbiology',
#   '003U0000018shSk',
#   'Tom',
#   'Lyons',
#   'Director of IT',
#   'tlyons@asmusa.org',
#   '',
#   '',
#   'DC',
#   '',
#   '',
#   '(202) 737-3600'],
#  ['001U000000DAcqM',
#   'American Society for Microbiology',
#   '003U000000J1F20',
#   'Michael',
#   'I.Goldberg',
#   'Executive Director',
#   'mgoldberg@asmusa.org',
#   '1752 N St. NW',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '(202) 737-3600'],
#  ['001U000000DAcqM',
#   'American Society for Microbiology',
#   '',
#   'Connie ',
#   'Herndon',
#   'Director',
#   'strategicalliances@asmusa.org',
#   '1752 N St. NW',
#   'Washington',
#   'DC',
#   '20036',
#   'United States',
#   '(202) 737-3600'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '0030B0000214P2m',
#   'Elissa',
#   "O'Brien",
#   'Vice President, Membership',
#   'elissa.obrien@shrm.org',
#   '1800 Duke St.',
#   'Alexandria',
#   'VA',
#   '22314',
#   'United States',
#   '(800) 283-7476 x6269'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000000Oqaoa',
#   'Scott',
#   'Ferrin',
#   'Field Service Director',
#   'scott.ferrin@shrm.org',
#   '2507 E. Mallory',
#   'Mesa',
#   'AZ',
#   '85213',
#   'United States',
#   '(703) 535-6417'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000000OqaoL',
#   'Laurie',
#   'McIntosh',
#   'Director, Member Engagement',
#   'laurie.mcintosh@shrm.org',
#   '1800 Duke Street',
#   'Alexandria',
#   'VA',
#   '22314',
#   'United States',
#   '(703) 535-6417'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000000OqaoM',
#   'Tara XX',
#   'Fournier XX',
#   'FORMER Manager, Member Engagement',
#   'tina.fournier@shrm.org',
#   '1800 Duke Street',
#   'Alexandria',
#   'VA',
#   '22314',
#   'United States',
#   '(703) 535-6417'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000000OqamE',
#   'Phyllis',
#   'Shurn-Hannah',
#   'Northeast Field Services Director',
#   '',
#   '111 Barley Sheaf Dr',
#   'Norristown',
#   'PA',
#   '19403',
#   'United States',
#   '(703) 535-6417'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000000OqamT',
#   'Sherry',
#   'Johnson',
#   'Field Svcs Dir Southwest Central Region',
#   'sherry.jorhnson@shrm.org',
#   'PO Box 5327',
#   'Round Rock',
#   'TX',
#   '78683',
#   'United States',
#   '(703) 535-6417'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000000OqazV',
#   'Dorothy',
#   'Knapp',
#   'Field Services Director',
#   'dorothy.knapp@shrm.org',
#   '',
#   '',
#   'FL',
#   '',
#   'United States',
#   '(703) 548-3440 or (800) 283-7476'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000000Oqaz0',
#   'Kristine',
#   'Hofmann',
#   'Manager, Business Operations',
#   'khofmann@shrm.org',
#   '',
#   '',
#   'VA',
#   '',
#   'United States',
#   '(703) 548-3440 x6082'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000000T5ZRA',
#   'Ronald',
#   'Brown',
#   'Manager, Financial Systems',
#   'rbrown@shrm.org',
#   '1800 Duke St Ste 100',
#   'Alexandria',
#   'VA',
#   '22314-3496',
#   '',
#   '(703) 548-3440'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000000T5jx6',
#   'Dianna',
#   'Gould',
#   'Human Resources Association Management Director',
#   'dianna.gould@shrm.org',
#   '1800 Duke St Ste 100',
#   'Alexandria',
#   'VA',
#   '22314-3496',
#   'United States',
#   '(703) 548-3440'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '0030B00001vUSuA',
#   'Anne-Margaret',
#   'Olsson',
#   'Manager, Social Networking & Online Communities',
#   'aolsson@shrm.org',
#   '1800 Duke St.',
#   'Alexandria',
#   'VA',
#   '22314',
#   'United States',
#   '(703) 535-6417'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000000T7y7P',
#   'Nancy',
#   'Conway',
#   'Field Services Director',
#   'nancy.conway@shrm.org',
#   '3800 Old Cheney Rd #101-313',
#   'Lincoln',
#   'NE',
#   '68516',
#   'United States',
#   'nancy.conway@shrm.org'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000001LAzey',
#   'Megan',
#   'Smith',
#   'Controller',
#   'megan.smith@shrm.org',
#   '1800 Duke St.',
#   'Alexandria',
#   'VA',
#   '22314',
#   'United States',
#   '(703) 535-6417'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000001NCqWw',
#   'Christina',
#   'Folz',
#   'Editor for HR Magazine',
#   'christina.folz@shrm.org',
#   '1800 Duke St.',
#   'Alexandria',
#   'VA',
#   '22314',
#   'United States',
#   '(703) 535-6417'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000001Npvlc',
#   'Aliah',
#   'Wright',
#   'Editor',
#   'aliah.wrightwarren@shrm.org',
#   '1800 Duke St.',
#   'Alexandria',
#   'VA',
#   '22314',
#   'United States',
#   '(703) 535-6417'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000001OgT4F',
#   'Mark',
#   'Langley',
#   'President & CEO',
#   'mark.langley@pmi.org',
#   '1800 Duke St.',
#   'Alexandria',
#   'VA',
#   '22314',
#   'United States',
#   '(610) 356-4600 x1145'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000000Hh6kR',
#   'Henry',
#   'Jackson',
#   'President and Chief Executive Officer',
#   'hjackson@shrm.org',
#   '1800 Duke Street',
#   'Alexandria',
#   'Virginia',
#   '22314',
#   '',
#   '(703) 548-3440'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U000001QTU7l',
#   'Crystal',
#   'Adair',
#   'Regional Administrator',
#   'cadair@shrm.org',
#   '1800 Duke St.',
#   'Alexandria',
#   'VA',
#   '22314',
#   'United States',
#   '(703) 535-6417'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U0000015zlbh',
#   'Cassidy',
#   'Solis',
#   'Workplace Flexibility Program Specialist',
#   'cassidy.solis@shrm.org',
#   '1800 Duke St.',
#   'Alexandria',
#   'VA',
#   '22314',
#   '',
#   '(703) 535-6086'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U0000015zlbj',
#   'J.',
#   'Robert Carr J.D., SPHR',
#   'Senior Vice President, Membership, Marketing and External Affairs',
#   'robert.carr@shrm.org',
#   '1800 Duke St.',
#   'Alexandria',
#   'VA',
#   '22314',
#   '',
#   '(703) 548-3440'],
#  ['001U000000DA8eJ',
#   'Society for Human Resource Management',
#   '003U0000015zlbk',
#   'Mary',
#   'Mohney',
#   'Chief Financial Officer',
#   'mary.mohney@shrm.org',
#   '1800 Duke St.',
#   'Alexandria',
#   'VA',
#   '22314',
#   '',
#   '(703) 548-3440'],
#  ...]

# %%
getAgencyDir()
# Out:
# Done
# [['Healthcare Financial Management Association',
#   'https://www.hfma.org/contact/'],
#  ['The National Rifle Association (NRA)',
#   'https://www.nraringoffreedom.com/meet-the-staff'],
#  ['American Academy of Pediatrics (AAP)',
#   'https://www.aap.org/en-us/Pages/Chapter-Executive-Director-Contact-List-and-Websites.aspx'],
#  ['United States Golf Association',
#   'http://www.usga.org/about/our-leadership.html'],
#  ['American Petroleum Institute', 'http://www.api.org/about/leadership-team'],
#  ['American Chemical Society',
#   'https://www.acs.org/content/acs/en/about/governance/executive-team-bios.html'],
#  ['Association of the United States Army', 'https://www.ausa.org/staff'],
#  ['Rotary International',
#   'https://www.rotary.org/en/about-rotary/our-leaders'],
#  ['American Society of Civil Engineers', 'http://www.asce.org/leadership/'],
#  ['American Psychological Association',
#   'http://www.apa.org/about/governance/board/index.aspx'],
#  ['ASIS International',
#   'https://www.asisonline.org/About-ASIS/Who-We-Are/Pages/default.aspx'],
#  ['Academy of Managed Care Pharmacy',
#   'http://www.amcp.org/AboutUs.aspx?id=16462'],
#  ['American Massage Therapy Association (AMTA) - HQ',
#   'https://www.amtamassage.org/About-AMTA/amta-staff.html'],
#  ['American Marketing Association (AMA)',
#   'https://www.ama.org/AboutAMA/Pages/Staff-Directory.aspx'],
#  ['American Pharmacists Association',
#   'http://www.pharmacist.com/governance-and-leadership'],
#  ['American Planning Association',
#   'https://www.planning.org/apaataglance/leadership/apastaff.htm'],
#  ['American Association of Diabetes Educators',
#   'https://www.diabeteseducator.org/about-aade/governance/senior-staff'],
#  ['American Veterinary Medical Association',
#   'https://www.avma.org/About/Governance/Leadership/Pages/default.aspx'],
#  ['National Association of Social Workers',
#   'http://www.naswdc.org/governance/cmtes/bodmembers.asp'],
#  ['American Association for Marriage & Family Therapy',
#   'http://www.aamft.org/iMIS15/AAMFT/Content/About_AAMFT/public_staff_directory.aspx'],
#  ['Georgia Society of Certified Public Accountants',
#   'http://www.gscpa.org/content/Staff.aspx'],
#  ['Institute of Industrial Engineers',
#   'http://www.iise.org/Details.aspx?id=24726'],
#  ['American Morgan Horse Association',
#   'https://www.morganhorse.com/about/who-we-are/staff/'],
#  ['Iowa Soybean Association',
#   'http://www.iasoybeans.com/about/staff-listing/'],
#  ['National Pork Producers Council', 'http://nppc.org/about-us/staff/'],
#  ['American Association of Endodontists (AAE)',
#   'http://www.aae.org/headquarters/'],
#  ['American Association of Law Libraries',
#   'https://www.aallnet.org/tm/contact'],
#  ['American Association of Medical Assistants',
#   'http://www.aama-ntl.org/volunteers/leaders'],
#  ['American Association of Nurse Anesthetists',
#   'http://www.aana.com/aboutus/Pages/Staff-Directors.aspx'],
#  ['American College of Foot and Ankle Surgeons (ACFAS)',
#   'http://www.acfas.org/About-Us/Contact-Us/'],
#  ['American College of Osteopathic Family Physicians',
#   'http://www.acofp.org/ACOFPIMIS/Acofporg/About_ACOFP/Staff/Acofporg/About_ACOFP/Staff.aspx'],
#  ['Nebraska Soybean Board', 'http://nebraskasoybeans.org/who-we-are/staff/'],
#  ['American Academy of Cosmetic Dentistry ', 'http://www.aacd.com/contact-us'],
#  ['National Association of Tax Professionals (NATP)',
#   'https://www.natptax.com/AboutNATP/Board/Pages/NATPStaff.aspx'],
#  ['National Funeral Directors Association',
#   'http://www.nfda.org/about-nfda/nfda-staff'],
#  ['National Science Teachers Association',
#   'http://www.nsta.org/about/collaboration/congresspast.aspx'],
#  ["National Sheriffs' Association",
#   'http://www.sheriffs.org/about-nsa/nsa-staff'],
#  ['National Society of Professional Engineers (NSPE)',
#   'https://www.nspe.org/membership/about-nspe/our-members/member-spotlight'],
#  ['Packaging Machinery Manufacturers Institute (PMMI)',
#   'https://www.pmmi.org/contact'],
#  ['American Dental Assistants Association',
#   'https://www.adaausa.org/About-ADAA/Staff-List'],
#  ['American Fence Association',
#   'http://www.americanfenceassociation.com/afa-staff/'],
#  ['American Foundry Society',
#   'http://www.afsinc.org/about/AFSStaffSpeakersBureau'],
#  ['American Nuclear Society', 'http://www.ans.org/about/staff/'],
#  ['Amusement & Music Operators Association',
#   'https://amoa.memberclicks.net/contact-information'],
#  ['Arthroscopy Association of North America (AANA)',
#   'http://www.aana.org/about-aana/aana-staff-members'],
#  ['Association For Corporate Growth (ACG)', 'https://www.acg.org/about/staff'],
#  ['Construction Financial Management Association',
#   'http://www.cfma.org/about/content.cfm?ItemNumber=968&navItemNumber=1018'],
#  ['Financial Executives International (FEI)',
#   'https://www.financialexecutives.org/About-FEI/Contact-Us.aspx'],
#  ['IEEE Photonics Society',
#   'http://www.photonicssociety.org/who-we-are/society-staff'],
#  ['IEEE Signal Processing Society',
#   'https://signalprocessingsociety.org/our-story/sps-staff'],
#  ['Institute of Management Accountants',
#   'https://www.imanet.org/about-ima/ima-leadership?ssopc=1'],
#  ['NAFA Fleet Management Association',
#   'https://www.nafa.org/About/Our-Team/Office-Directions-Info.aspx'],
#  ['National Kitchen and Bath Association',
#   'https://www.nkba.org/About/Leadership/SeniorStaff.aspx'],
#  ['New Jersey Society of Certified Public Accountants',
#   'https://njcpa.org/about/staff'],
#  ['New Jersey State Bar Association',
#   'https://tcms.njsba.com/personifyebusiness/Contact/NJSBAStaff.aspx'],
#  ['Society of Naval Architects and Marine Engineers',
#   'http://www.sname.org/oursociety/staff'],
#  ['Plumbing, Heating, Cooling Contractors - National Association (PHCC)',
#   'http://www.phccweb.org/About/content.cfm?ItemNumber=731&navItemNumber=10213'],
#  ['Registry of Interpreters for the Deaf',
#   'http://rid.org/about-rid/rid-headquarters-staff/'],
#  ["Sheet Metal and Air Conditioning Contractors' National Association",
#   'https://www.smacna.org/about-us/connect-with-smacna/national-staff'],
#  ['Society for Marketing Professional Services',
#   'https://www.smps.org/About/Staff-Directory/'],
#  ['Society of American Military Engineers (SAME)',
#   'http://www.same.org/Meet-the-National-Staff'],
#  ['Society of Nuclear Medicine and Molecular Imaging',
#   'http://www.snmmi.org/AboutSNMMI/Content.aspx?ItemNumber=4133&navItemNumber=22071'],
#  ['The National Association for Music Education (Formerly MENC)',
#   'https://nafme.org/about/staff/'],
#  ['Association of Information Technology Professionals (AITP)',
#   'https://www.comptia.org/about-us/executive-staff'],
#  ['Association of Legal Administrators (ALA)',
#   'http://www.alanet.org/membership/member-directory'],
#  ['Association of Pediatric Hematology/Oncology Nurses',
#   'http://aphon.org/about-us/staff'],
#  ['Clinical Laboratory Management Association (CLMA)',
#   'http://www.clma.org/p/cm/ld/fid=122'],
#  ['Coin Laundry Association', 'http://www.coinlaundry.org/about/staff'],
#  ['Council of Residential Specialists',
#   'https://crs.com/about-us/staff-directory'],
#  ['Healthcare Information and Management Systems Society',
#   'http://www.himss.org/contactus'],
#  ['American Geriatrics Society',
#   'http://www.americangeriatrics.org/about-us/leadership/ags-staff'],
#  ['American Institute of Graphic Arts (AIGA)',
#   'http://www.aiga.org/aiga-staff'],
#  ['Association of Junior Leagues International (AJLI)',
#   'https://www.ajli.org/?nd=p-who-leadership-staff'],
#  ['Water Environment Federation',
#   'https://www.wef.org/about/contact-us/staff-directory/'],
#  ['Institute Of Real Estate Management',
#   'http://www.irem.org/about-irem/Headquarter-Staff'],
#  ['International Society of Arboriculture',
#   'http://www.isa-arbor.com/about/staff/staffDirectory.aspx'],
#  ['Legal Marketing Association', 'https://www.legalmarketing.org/contact'],
#  ['Medical Library Association', 'http://www.mlanet.org/p/cm/ld/fid=25'],
#  ['Metals Service Center Institute',
#   'https://www.msci.org/login?returnurl=%2fabout-us%2fstaff-list'],
#  ['National Association of the Remodeling Industry (NARI)',
#   'http://www.nari.org/industry/staff/'],
#  ['Professional Convention Management Association',
#   'https://www.pcma.org/about/pcma-leadership/'],
#  ['Turnaround Management Association', 'https://turnaround.org/about/staff'],
#  ['User Experience Professionals Association',
#   'https://uxpa.org/about/board-directors'],
#  ['Warehousing Education and Research Council (WERC)',
#   'https://www.werc.org/about/werc_staff.aspx'],
#  ['Water Quality Association', 'https://www.wqa.org/about-us/our-team'],
#  ["Women's Council of REALTORS",
#   'http://www.wcr.org/leadership/national-officer-team/'],
#  ['National Fire Sprinkler Association', 'http://www.nfsa.org/page/NFSADepts'],
#  ['National League for Nursing',
#   'http://www.nln.org/about/who%27s-who-at-the-nln/management-team-bios'],
#  ['New York State Society of Certified Public Accountants (NYSSCPA)',
#   'http://www.nysscpa.org/about/about-nysscpa/staff-directory#sthash.lQOv7zhK.dpbs'],
#  ['Northeastern Retail Lumber Association',
#   'http://www.nrla.org/NRLA/AboutUs/Meet_Our_Staff/NRLA/About_Us/Meet_Our_Staff.aspx?hkey=9e3cbc5f-3310-4661-9507-84038ca0846d'],
#  ['Association of College Unions International (ACUI)',
#   'http://www.acui.org/about/staff#'],
#  ['National Precast Concrete Association', 'http://precast.org/npca/staff/'],
#  ['Golf Course Superintendents Association of America',
#   'https://www.gcsaa.org/about-gcsaa/leadership-profiles/department-leadership-team'],
#  ['Risk and Insurance Management Society, Inc. (RIMS)',
#   'https://www.rims.org/Pages/Staff-Directory.aspx'],
#  ['Public Relations Society of America',
#   'https://www.prsa.org/about/about-prsa/meet-our-leadership-team/'],
#  ['Amateur Trapshooting Association',
#   'http://www.shootata.com/ContacttheATA.aspx#officestaff'],
#  ['American Ceramics Society', 'http://ceramics.org/about/staff-directory-2'],
#  ['ASM International',
#   'http://www.asminternational.org/about/contact/staff-directory;jsessionid=FD461B3BA039E3BCC8FA2B5CFBFA19FF'],
#  ['Association for Middle Level Education',
#   'https://www.amle.org/AboutAMLE/AMLEStaff/tabid/400/Default.aspx'],
#  ['Association of Nurses in AIDS Care',
#   'https://www.nursesinaidscare.org/i4a/pages/index.cfm?pageid=3614'],
#  ['Educational Theatre Association',
#   'https://www.schooltheatre.org/about/contact/staff'],
#  ['Music Teachers National Association',
#   'http://www.mtna.org/about-mtna/mtna-staff/'],
#  ['Alabama Association of Realtors',
#   'http://www.alabamarealtors.com/about/staff'],
#  ['Alabama Association of School Boards',
#   'http://www.alabamaschoolboards.org/about/our-team'],
#  ["Alabama Cattlemen's Association", 'https://www.bamabeef.org/p/about/150'],
#  ['Arizona Association of Realtors',
#   'https://www.aaronline.com/about-us/leadership/staff-directory/'],
#  ['Arizona School Boards Association'],
#  ['Sports Turf Managers Association', 'http://www.stma.org/headquarters'],
#  ['American Saddlebred Horse Association',
#   'https://www.asha.net/aboutus/asha/stafflist'],
#  ['United States Equestrian Federation',
#   'https://www.usef.org/about-us/staff-directory'],
#  ['State Bar of Arizona',
#   'http://www.azbar.org/aboutus/leadership/seniorleadership'],
#  ['Association of California School Administrators',
#   'https://www.acsa.org/About-Us'],
#  ['Infusion Nurses Society', 'http://www.ins1.org/AboutUs/INSTeam.aspx'],
#  ['Ohio Contractors Association',
#   'https://www.ohiocontractors.org/OCAColors/About_OCA/Meet_the_OCA_Staff/OCAColors/AboutOCA/OCA_Staff/Copy_of_Meet_the_OCA_Staff.aspx?hkey=57c5f7e3-1634-4710-bc74-27a4faeeb6f3'],
#  ['Ohio State Bar Association',
#   'https://www.ohiobar.org/AboutOSBA/People/Pages/StaffDirectory.aspx'],
#  ['California Dental Association',
#   'https://www.cda.org/about-cda/leadership/executive-committee'],
#  ['California School Boards Association',
#   'https://www.csba.org/About/Leadership/ExecutiveStaff.aspx'],
#  ['California Society of Certified Public Accountants',
#   'http://www.calcpa.org/who-we-are/contact-us/calcpa-and-calcpa-education-foundation-team-directory'],
#  ['American Concrete Institute (ACI)',
#   'https://www.concrete.org/contactus/staffdirectory.aspx'],
#  ['American Choral Directors Association',
#   'https://acda.org/page.asp?page=contactus'],
#  ['Oregon Dental Association',
#   'http://www.oregondental.org/about-us/contact-us/meet-the-staff'],
#  ['American Academy of Neurology',
#   'https://www.aan.com/membership/executive-staff/'],
#  ['Grain Elevator and Processing Society',
#   'https://www.geaps.com/about-geaps/staff/'],
#  ['Association of Pennsylvania State College and University Faculties',
#   'http://www.apscuf.org/about-us/leadershipstaff-directory/'],
#  ['Society of Chartered Property and Casualty Underwriters (CPCU)',
#   'https://www.cpcusociety.org/about-us/about-society/who-to-call'],
#  ['Hearth, Patio and Barbecue Association (HPBA)',
#   'http://www.hpba.org/Contact/Executive-Staff'],
#  ['American Society of Farm Managers and Rural Appraisers (ASFMRA)',
#   'http://www.asfmra.org/national-staff/'],
#  ['Arabian Horse Association',
#   'https://www.arabianhorses.org/additional/leadership/staff-directory/'],
#  ['Association of Surgical Technologists',
#   'http://www.ast.org/State_Assemblies/State_Assembly_Leadership_Committee/'],
#  ['Colorado Medical Society', 'http://www.cms.org/about/contact'],
#  ['International Mountain Bicycling Association (IMBA)',
#   'https://www.imba.com/about/staff'],
#  ['National Association of RV Parks and Campgrounds',
#   'http://www.arvc.org/about_arvc/contact.aspx'],
#  ['Minnesota State Bar Association',
#   'http://www.mnbar.org/about-msba/contact-us#.WYAkBIiGPIU'],
#  ['Oncology Nursing Society', 'https://www.ons.org/about/leadership/ceo'],
#  ['Pennsylvania Association of Realtors',
#   'https://www.parealtor.org/who-we-are/staff/'],
#  ['Pennsylvania Association of School Business Officials (PASBO)',
#   'http://www.pasbo.org/staff'],
#  ['Pennsylvania Institute of Certified Public Accountants (PICPA)',
#   'https://www.picpa.org/belong-engage/who-we-are/contact-picpa'],
#  ['Society Of Cable Telecommunications Engineers Inc',
#   'http://www.scte.org/SCTE/About/Staff/SCTE/About/SCTEStaff.aspx?Dept=LEAD&hkey=8dbcfc6d-2837-4cb7-8474-95cc2e2d20cf'],
#  ['Society of Financial Service Professionals',
#   'http://national.societyoffsp.org/page/bodlist'],
#  ['SSPC: the Society for Protective Coatings'],
#  ['The Risk Management Association', 'http://www.rmahq.org/ContactUs/'],
#  ['Society of Plastics Engineers',
#   'http://www.4spe.org/Leadership/Content.aspx?ItemNumber=6486&navItemNumber=6487'],
#  ['American Accounting Association',
#   'http://aaahq.org/About/Directories/Staff'],
#  ['American Association of Occupational Health Nurses',
#   'http://aaohn.socious.com/page/contact-us'],
#  ['American Angus Association', 'http://www.angus.org/Assoc/Employee.aspx'],
#  ['American Association of Orthodontists (AAO)',
#   'https://www.aaoinfo.org/about-aao/contact-us'],
#  ['American Soybean Association',
#   'https://soygrowers.com/about-asa/st-louis/'],
#  ['International Association of Administrative Professionals (IAAP)',
#   'http://www.iaap-hq.org/staff/'],
#  ['International Association of Assessing Officers',
#   'http://www.iaao.org/wcm/About/Staff/wcm/About_Us_Content/Staff.aspx'],
#  ['Missouri Soybean Association', 'https://mosoy.org/meet-the-staff/'],
#  ['Painting and Decorating Contractors of America',
#   'http://www.pdca.org/?page=StaffDirectory'],
#  ['National Golf Course Owners Association (NGCOA)',
#   'http://www.ngcoa.org/pageview.asp?doc=218'],
#  ['American Association for Laboratory Animal Science',
#   'https://www.aalasfoundation.org/About-Us'],
#  ['Christian Medical & Dental Association (CMDA)',
#   'https://cmda.org/staff/Staff'],
#  ['College and University Professional Association for Human Resources (CUPA-HR)',
#   'http://www.cupahr.org/about/staff.aspx'],
#  ['American Association for Respiratory Care (AARC)',
#   'http://c.aarc.org/contact_us/'],
#  ['American Association of Professional Landmen',
#   'http://www.landman.org/about-aapl/staff'],
#  ['American Welding Society',
#   'http://awsnow.org/index.php/employees/last_name/P40/'],
#  ['Florida REALTORS',
#   'http://www.floridarealtors.org/LegislativeCenter/ContactUs/index.cfm'],
#  ['American Simmental Association',
#   'http://simmental.org/site/index.php/contact/asa-publication-staff'],
#  ['American Paint Horse Association',
#   'http://apha.com/contacts/staffdirectory/'],
#  ['Association of Progressive Rental Organizations',
#   'https://www.rtohq.org/board-staff/'],
#  ['Association of Texas Professional Educators',
#   'http://www.atpe.org/en/About-ATPE/State-Office-Staff'],
#  ['Electronic Security Association', 'http://esaweb.org/About/Our-Team'],
#  ['Hospitality Financial and Technology Professionals (HFTP)',
#   'https://www.hftp.org/contact_us/staff_directory/'],
#  ['International Association of Exhibitions and Events (IAEE)',
#   'http://www.iaee.com/about/leadership/our_staff/'],
#  ['NACE International (The Corrosion Society)',
#   'https://www.nace.org/About-NACE/Board-Bios/'],
#  ['National Athletic Trainers Association',
#   'https://www.nata.org/about/nata-staff'],
#  ['International Society for Pharmaceutical Engineering (ISPE)',
#   'http://www.ispe.org/staff-directory'],
#  ['Miami Association of Realtors', 'http://www.miamire.com/about/leaders/ypn'],
#  ['Association of Energy Engineers',
#   'https://www.aeecenter.org/about-aee/aee-staff'],
#  ['CoreNet Global',
#   'http://www.corenetglobal.org/about/tcontent.aspx?ItemNumber=21166&navItemNumber=20842'],
#  ['Promotional Products Association International',
#   'http://www.ppai.org/association/about/ppai-executive-team/'],
#  ['Society of Petroleum Engineers', 'http://www.spe.org/about/executives.php'],
#  ['Texas Association of REALTORS',
#   'https://www.texasrealestate.com/staff-directory'],
#  ['Texas Association of School Business Officials',
#   'http://www.tasbo.org/personifymainorgsite/about-tasbo/about-us/staff'],
#  ['Texas Land Title Association',
#   'https://www.tlta.com/TLTA/About/staff/TLTA/About/Staff.aspx?hkey=5169289c-c896-4cd6-93e0-90310995b786'],
#  ['United States Bowling Congress',
#   'https://www.bowl.com/Team_USA/Team_USA_Home/Team_Members/'],
#  ['American Society of Anesthesiologists',
#   'https://www.asahq.org/about-asa/contact-us'],
#  ['American Society of Interior Designers (ASID)',
#   'https://www.asid.org/staff/staff'],
#  ['American Society of Landscape Architects (ASLA)',
#   'https://www.asla.org/staff.aspx'],
#  ['American Trucking Association', 'http://www.trucking.org/About.aspx'],
#  ['American Water Works Association (AWWA)',
#   'https://www.awwa.org/about-us/leadership/staff-leadership.aspx'],
#  ['Appraisal Institute',
#   'http://www.appraisalinstitute.org/about/leadership/'],
#  ['Association of Corporate Counsel',
#   'http://www.acc.com/aboutacc/contactus/directory.cfm'],
#  ['International Public Management Association for Human Resources',
#   'http://ipma-hr.org/about-us/contact-us'],
#  ['International Sign Association',
#   'http://www.signs.org/AboutISA/Contact.aspx'],
#  ['Licensing Executives Society (LES)',
#   'http://www.lesusacanada.org/?page=staff'],
#  ['Military Officers Association of America (MOAA)',
#   'http://www.moaa.org/Content/About-MOAA/Meet-our-Leaders/Key-Staff/Key-Staff.aspx'],
#  ['National Academy of Elder Law Attorneys, Inc.',
#   'https://www.naela.org/Web/About_Tab/About_Tab_Main_Landing/Contact_Staff.aspx'],
#  ['National Apartment Association (NAA)', 'https://www.naahq.org/about/staff'],
#  ['National Association for College Admission Counseling',
#   'https://www.nacacnet.org/contact/staff-directory/'],
#  ['National Association of Elementary School Principals',
#   'https://www.naesp.org/naesp-staff'],
#  ['National Association of Insurance and Financial Advisors (NAIFA)',
#   'http://www.naifa.org/about-naifa/staff-directory'],
#  ['National Association of Professional Insurance Agents',
#   'http://www.pianet.org/contact'],
#  ['National Association of Secondary School Principals (NASSP)',
#   'https://www.principals.org/who-we-are/board-of-directors'],
#  ['Automotive Service Association', 'http://asashop.org/staff-directory/'],
#  ['Building Owners and Managers Association International',
#   'http://www.boma.org/about/boma-staff/Pages/default.aspx'],
#  ['National Automatic Merchandising Association',
#   'https://www.namanow.org/about-us/staff-directory'],
#  ['National Automobile Dealers Association',
#   'https://www.nada.org/nadastaff/'],
#  ['National Contract Management Association (NCMA)',
#   'http://www.ncmahq.org/discover-our-profession/what-is-ncma/staff'],
#  ['National Council of Teachers of Mathematics (NCTM)',
#   'http://www.nctm.org/About/Staff/'],
#  ['National Defense Industrial Association (NDIA)',
#   'http://www.ndia.org/about/contact-us/staff-directory'],
#  ['National Head Start Association', 'https://www.nhsa.org/about-us/staff'],
#  ['National Hospice & Palliative Care Organization',
#   'https://www.nhpco.org/about/nhpco-staff'],
#  ['National Investor Relations Institute (NIRI)',
#   'https://www.niri.org/contact-us'],
#  ['National School Boards Association',
#   'https://www.nsba.org/about-us/nsba-staff-contact-information'],
#  ['Financial Planning Association (FPA)',
#   'https://www.onefpa.org/about/Pages/Staff-Directory.aspx'],
#  ['Government Finance Officers Association of the United States and Canada',
#   'http://www.gfoa.org/about-gfoa/staff-directory'],
#  ['Independent Community Bankers of America (ICBA)',
#   'http://www.icba.org/bancard/about-us/bancard-staff-directory'],
#  ['Institute of Food Technologists (IFT)',
#   'http://www.ift.org/about-us/contact-us/staff-directory.aspx'],
#  ['Institute of Scrap Recycling Industries, Inc.',
#   'http://www.isri.org/about-isri/staff#.WYVuJYiGPIU'],
#  ['Institute of Transportation Engineers',
#   'http://www.ite.org/directories/index.asp'],
#  ['LeadingAge (American Association of Homes and Services for the Aging)',
#   'http://www.leadingage.org/Staff'],
#  ['Mortgage Bankers Association of America',
#   'https://www.mba.org/who-we-are/management'],
#  ['National Association for Home Care and Hospice (NAHC)',
#   'http://www.nahc.org/about/board-of-directors/'],
#  ['National Association for the Education of Young Children',
#   'http://www.naeyc.org/about/exec/executiveTeam'],
#  ['National Association of College Stores',
#   'https://www.nacs.org/AboutNACS/staffdirectory.aspx'],
#  ['National Association of Corporate Directors',
#   'https://blog.nacdonline.org/author/nacd-staff/'],
#  ['National Association of Criminal Defense Lawyers',
#   'https://www.nacdl.org/people.aspx?type=staff'],
#  ['National Association of Enrolled Agents',
#   'https://www.naea.org/staff-bios'],
#  ['National Association of Health Underwriters (NAHU)',
#   'https://www.nahu.org/about/staff.cfm'],
#  ['National Association of Home Builders (NAHB)',
#   'https://www.nahb.org/en/find/directory-nahbstaff.aspx#sort=%40flastname40069%20ascending'],
#  ['National Association of Manufacturers',
#   'http://www.nam.org/About/Staff-Leadership/'],
#  ['National Association of Medical Staff Services',
#   'http://www.namss.org/About/MeettheNAMSSStaff.aspx'],
#  ['National Association of Student Financial Aid Administrators',
#   'https://www.nasfaa.org/Contact_Us'],
#  ['National Association of Theatre Owners',
#   'http://www.natoonline.org/contact-nato/'],
#  ["National Cattlemen's Beef Association",
#   'http://www.beefusa.org/seniorleadershipteam.aspx'],
#  ['National Corn Growers Association',
#   'http://www.ncga.com/about-ncga/ncga-staff'],
#  ['National Recreation and Parks Association',
#   'http://www.nrpa.org/About-National-Recreation-and-Park-Association/leadership/staff/'],
#  ['National Safety Council',
#   'http://www.nsc.org/Connect/Pages/nsc-executive-management-team.aspx'],
#  ['Society for American Archaeology (SAA)',
#   'http://www.saa.org/AbouttheSociety/Contact/SAAStaffDirectory/tabid/259/Default.aspx'],
#  ['Society for Neuroscience',
#   'https://www.sfn.org/about/careers-and-staff/staff-list'],
#  ['Society of Industrial and Office Realtors (SIOR)',
#   'http://www.sior.com/about/sior-staff'],
#  ['Solar Energy Industries Association (SEIA)', 'http://www.seia.org/staff'],
#  ['Telecommunications Industry Association',
#   'https://www.tiaonline.org/about/staff'],
#  ['The American Institute of Architects (AIA)',
#   'https://www.aia.org/leadership'],
#  ['American Society for Public Administration (ASPA)',
#   'http://www.aspanet.org/ASPA/About-ASPA/ASPA-Staff/ASPA/About-ASPA/ASPA-Staff.aspx?hkey=e223bd7f-aabe-4922-960d-2728a44581af'],
#  ['American Association of Physicists in Medicine',
#   'http://www.aapm.org/org/contactinfo.asp'],
#  ['American Boat and Yacht Council', 'http://abycinc.org/?page=theteam'],
#  ['American College of Gastroenterology',
#   'http://gi.org/media/about-acg/#Headquarters'],
#  ['American College of Nurse-Midwives', 'http://www.acnm.org/Staff-Directory'],
#  ['American Nurses Association (ANA)',
#   'http://www.nursingworld.org/FunctionalMenuCategories/AboutANA/Leadership-Governance/leadership-staff2.html'],
#  ['American Occupational Therapy Association (AOTA)',
#   'https://www.aota.org/Education-Careers/Accreditation/Contacts.aspx'],
#  ['American Physiological Society',
#   'http://www.the-aps.org/fm/Staff-Directory'],
#  ['American Podiatric Medical Association',
#   'https://www.apma.org/workingforyou/content.cfm?ItemNumber=1368&&navItemNumber=626'],
#  ['American Society for Biochemistry and Molecular Biology',
#   'http://www.asbmb.org/about/governance/staff/'],
#  ['American Speech-Language-Hearing Association',
#   'http://www.asha.org/about/governance/cso/'],
#  ['Association for Financial Professionals',
#   'https://www.afponline.org/about/learn-more/press-releases/press-room/leadership'],
#  ['Association for Information and Image Management International',
#   'http://www.aiim.org/About-Section/A-Team'],
#  ['Association of Career and Technical Education (ACTE)',
#   'https://www.acteonline.org/webForm.aspx?ekfrm=134'],
#  ['Association of Public Health Laboratories (APHL)',
#   'https://www.aphl.org/aboutAPHL/Pages/Senior-Staff.aspx'],
#  ['National Association of Credit Management',
#   'https://nacm.org/board-of-directors.html'],
#  ['National Association of School Nurses (NASN)',
#   'https://www.nasn.org/about-nasn/nasn-staff'],
#  ['National Association of School Psychologists',
#   'http://apps.nasponline.org/about-nasp/contact-us.aspx'],
#  ['National Electrical Contractors Association Inc',
#   'http://www.necanet.org/about-us/staff-leadership/staff-directory/lists/staff-leadership/traci-pickus'],
#  ['Parenteral Drug Association (PDA)', 'https://www.pda.org/footer/staff'],
#  ['Regulatory Affairs Professionals Society',
#   'http://www.raps.org/SearchRegFocus.aspx?tag=staff'],
#  ['Society of American Foresters',
#   'https://www.eforester.org/Main/About/Staff/Main/About/Staff.aspx?hkey=957bcea9-a466-4573-97ad-cf57f096ed99'],
#  ['Society of Fire Protection Engineers (SFPE)',
#   'http://www.sfpe.org/?page=Staff'],
#  ['Solid Waste Association of North America (SWANA) ',
#   'https://swana.org/ContactUs.aspx'],
#  ['US Lacrosse', 'https://www.uslacrosse.org/about-us-lacrosse/our-staff'],
#  ['Virginia Society of Certified Public Accountants',
#   'https://www.vscpa.com/content/about_vscpa/contact/staff.aspx'],
#  ['Air Conditioning Contractors of America',
#   'http://www.acca.org/about-acca/staff'],
#  ['Air Force Association', 'https://www.afa.org/contactus'],
#  ['American Anthropological Association (AAA)',
#   'http://www.americananthro.org/StaffList.aspx?navItemNumber=668'],
#  ['American Association of School Administrators (AASA)',
#   'http://www.aasa.org/content.aspx?id=1328'],
#  ['American Chiropractic Association',
#   'https://www.acatoday.org/About/Board-of-Governors'],
#  ['American College of Health Care Administrators (ACHCA)',
#   'https://achca.memberclicks.net//contact-us-'],
#  ['American College of Radiology (ACR)',
#   'https://www.acr.org/About-Us/Staff-Directory'],
#  ['American Industrial Hygiene Association',
#   'https://www.aiha.org/about-aiha/contact-us/Pages/AIHA-Senior-Leadership-Team.aspx'],
#  ['American Institute of Aeronautics and Astronautics (AIAA)',
#   'https://www.aiaa.org/StaffDirectory.aspx?id=4773'],
#  ['American Physical Therapy Association', 'http://www.apta.org/Staff/'],
#  ['American School Counselor Association (ASCA)',
#   'https://www.schoolcounselor.org/school-counselors-members/contact-us'],
#  ['American Society of Appraisers',
#   'http://www.appraisers.org/About/contact-asa'],
#  ['Academy Of Nutrition And Dietetics',
#   'http://www.eatrightpro.org/resources/acend/about-acend/acend-staff'],
#  ['ACPA - College Student Educators International',
#   'http://www.myacpa.org/international-office-staff'],
#  ['American Academy of Child and Adolescent Psychiatry',
#   'https://www.aacap.org/aacap/Regional_Organizations/EPSNJCCAP/Officers_and_Staff.aspx'],
#  ['American Advertising Federation',
#   'https://www.aaf.org/AAFMemberR/WHO_WE_ARE/Our_Team/AAFMemberR/Who_We_Are/Staff.aspx?hkey=4f730386-2468-4d4e-a467-f16ff0e3766c'],
#  ['American Association of Colleges for Teacher Education (AACTE)',
#   'http://aacte.org/about-aacte/staff'],
#  ['American Association of University Professors',
#   'https://www.aaup.org/about/staff'],
#  ['American Society of Travel Agents',
#   'https://www.asta.org/content.cfm?ItemNumber=772&navItemNumber=11754'],
#  ['American Staffing Association (ASA)',
#   'https://americanstaffing.net/asa/american-staffing-association-leadership-staff/asa-staff-directory/'],
#  ['American Statistical Association',
#   'http://www.amstat.org/ASA/About/Staff-Directory.aspx?hkey=64bcd54c-7df2-4053-9fd4-04cfb4ba8eb2'],
#  ['American String Teachers Association',
#   'https://www.astastrings.org/Web/About_ASTA/Staff_Associates.aspx'],
#  ['American Subcontractors Association',
#   'https://www.asaonline.com/eweb/DynamicPage.aspx?Site=asa&WebKey=175b29c0-dcac-463e-ae22-310bfa4644c1'],
#  ['American Translators Association',
#   'https://www.atanet.org/aboutus/contactus.php'],
#  ['APPA - Association Of Higher Education Facilities Officers',
#   'http://www.appa.org/aboutUs/staff.cfm'],
#  ['Associated General Contractors of America (AGCA)',
#   'https://www.agc.org/about-us/staff-directory'],
#  ['Association for Healthcare Philanthropy',
#   'http://www.ahp.org/Home/About_Us/associates/Home/About_Us/Associates.aspx?hkey=2d95606b-53ce-414b-a03d-cb4d964642dc'],
#  ['Association for Supervision and Curriculum Development (ASCD)',
#   'http://www.ascd.org/about-ascd.aspx'],
#  ['Association for Unmanned Vehicle Systems International (AUVSI)',
#   'http://www.auvsi.org/who-we-are/team'],
#  ['Association of Air Medical Services',
#   'http://aams.org/staff-category/aams-staff/'],
#  ['Association of Government Accountants (AGA)',
#   'https://www.agacgfm.org/About/Contact-Us.aspx'],
#  ['Association of Old Crows',
#   'http://www.crows.org/contact-us/aoc-staff.html'],
#  ['Association of School Business Officials International',
#   'http://asbointl.org/about/contact-us'],
#  ['Automotive Recyclers Association (ARA)',
#   'http://a-r-a.org/who-we-are/ara-team/'],
#  ['Casualty Actuarial Society',
#   'http://www.casact.org/about/index.cfm?fa=contact'],
#  ['Club Managers Association of America', 'http://www.cmaa.org/staff/'],
#  ['American Coatings Association (ACA)',
#   'http://www.paint.org/about-aca/staff/'],
#  ['American College of Surgeons (ACS)',
#   'https://www.facs.org/about-acs/governance/exec-staff'],
#  ['American Congress of Obstetricians and Gynecologists',
#   'https://www.acog.org/About-ACOG/Executive-Staff'],
#  ['American Council of Engineering Companies (ACEC)',
#   'http://www.acec.org/about/staff-directory/'],
#  ['American Farm Bureau Federation', 'http://www.fb.org/about/directory'],
#  ['American Foreign Service Association (AFSA)',
#   'http://www.afsa.org/afsa-staff'],
#  ['American Forest & Paper Association',
#   'http://www.afandpa.org/about/af-pa-staff'],
#  ['American Land Title Association',
#   'https://www.alta.org/about/contact-alta.cfm'],
#  ['American Library Association',
#   'http://www.ala.org/aboutala/ala-staff-directory'],
#  ['American Public Health Association',
#   'https://www.apha.org/about-apha/executive-board-and-staff/apha-staff'],
#  ['American Public Power Association',
#   'https://ebiz.publicpower.org/APPAEbiz/Login.aspx'],
#  ['American Public Works Association',
#   'http://www.apwa.net/MYAPWA/About/Staff/MyApwa/Apwa_Public/About/Contact_Us.aspx?hkey=8556f1ac-7f3f-472b-ac7c-afaa0e247678'],
#  ['American Rental Association (ARA)',
#   'http://www.ararental.org/About-Us/ARA-Leadership-and-Staff/ARA-Staff-Org-Chart'],
#  ['Construction Management Association of America',
#   'http://cmaanet.org/cmaa-staff'],
#  ['Construction Specifications Institute',
#   'https://www.csiresources.org/institute/staff'],
#  ['Distributive Education Clubs of America (DECA)',
#   'https://www.deca.org/about/deca-staff/'],
#  ['Employee Assistance Professionals Association',
#   'http://www.eapassn.org/contact'],
#  ['Enlisted Association of the National Guard of the United States',
#   'https://eangus.org/about-us/'],
#  ['Federal Bar Association',
#   'http://www.fedbar.org/About-Us/National-Staff.aspx'],
#  ['Future Business Leaders of America - Phi Beta Lambda (FBLA-PBL)',
#   'http://www.fbla-pbl.org/contact/'],
#  ['Independent Electrical Contractors', 'http://www.ieci.org/staff'],
#  ['Independent Insurance Agents & Brokers of America, Inc.',
#   'http://www.independentagent.com/ContactUs/Pages/staff/default.aspx'],
#  ['Infectious Diseases Society of America',
#   'http://www.idsociety.org/IDSA_Staff/'],
#  ['International Association of Chiefs of Police',
#   'http://www.theiacp.org/Executive-Staff'],
#  ['American Society of Home Inspectors',
#   'http://www.homeinspector.org/ASHI-staff'],
#  ['Lean Construction Institute',
#   'https://www.leanconstruction.org/about-us/lci-staff/'],
#  ['Professional Club Marketing Association',
#   'http://www.askpcma.org/Default.aspx?p=DynamicModule&pageid=355668&vnf=1'],
#  ['Legal Defense Fund Of The Peace Officers Research Association Of California',
#   'https://porac.org/about/staff/'],
#  ['Medical Group Management Association',
#   'http://www.mgma.com/about/about-mgma-medical-group-management/contact-mgma'],
#  ['Toastmasters International',
#   'https://www.toastmasters.org/footer/magazinefooterlinks/staff'],
#  ['American College of Cardiology, Inc (ACC)',
#   'http://chapteraffairs.acc.org/main/Pages/Oscar-ContactUs.aspx'],
#  ['Association for Women in Science',
#   'https://www.awis.org/about-awis/staff/'],
#  ['NAADAC, the Association for Addiction Professionals',
#   'https://www.naadac.org/staff-directory'],
#  ['National Society Collegiate Scholars', 'http://www.nscs.org/nscs-team/'],
#  ['National Association of Industrial and Office Properties (NAIOP)',
#   'https://www.naiop.org/en/About-NAIOP/Who-We-Are/Contact-Us.aspx#'],
#  ['Brain Injury Association of America',
#   'http://www.biausa.org/About-Us/contact.htm'],
#  ['School Nutrition Association',
#   'https://schoolnutrition.org/AboutSNA/SNAStaff/'],
#  ['The Institute of Internal Auditors Inc (HQ)',
#   'https://na.theiia.org/about-us/Pages/IIA-Leadership.aspx'],
#  ['National Association of State Workforce Agencies',
#   'https://www.naswa.org/?action=staff_directory'],
#  ['National Association for Multi-Ethnicity In Communications (NAMIC)',
#   'http://namic.com/the-team/'],
#  ['Veterinary Medical Association Executives'],
#  ['Northern California Golf Association (NCGA)',
#   'https://ncga.org/about-us/staff/'],
#  ['Texas Retired Teachers Association',
#   'http://www.trta.org/contact-us/trta-staff/'],
#  ['National Society for Histotechnology', 'http://nsh.org/content/contact-us'],
#  ['American Inns of Court',
#   'http://home.innsofcourt.org/AIC/About_Us/Our_Staff/AIC/AIC_About_Us/American_Inns_of_Court_Foundation_Staff.aspx?hkey=e5d8b235-f1a0-4807-8991-d60f9b80e5d0'],
#  ['HDI', 'http://www.thinkhdi.com/about/contact.aspx'],
#  ['Drohan Management Group', 'http://www.drohanmgmt.com/about/our-team/'],
#  ['Bond Association Management',
#   'http://www.bondassociationmanagement.com/team/'],
#  ['Associations International',
#   'http://www.associationsinternational.com/WhyAI/People.aspx'],
#  ['International Association of Healthcare Central Service Materiel Management (IAHCSMM)',
#   'https://www.iahcsmm.org/about/contact-us.html'],
#  ['American Medical Informatics Association (AMIA)',
#   'https://www.amia.org/about-amia/leadership/staff'],
#  ['Commercial Finance Association',
#   'https://www.cfa.com/eweb/DynamicPage.aspx?Site=CFA&Webcode=abt_staff'],
#  ['The Global Association for Corporate Real Estate (CoreNet Global)',
#   'http://www.corenetglobal.org/about/tcontent.aspx?ItemNumber=21166&navItemNumber=20842'],
#  ['National Cannabis Industry Association',
#   'https://thecannabisindustry.org/staff/'],
#  ['National Association of Pediatric Nurse Practitioners',
#   'https://www.napnap.org/meet-your-national-office-staff'],
#  ['National Real Estate Investors Association',
#   'https://nationalreia.org/leadership/'],
#  ['Human Resources Professionals Association',
#   'https://www.hrpa.ca/abouthrpa_/Pages/Contact-Us.aspx'],
#  ['Association for Vascular Access', 'http://www.avainfo.org/?page=OurStaff'],
#  ['P & N Association Management',
#   'http://www.pnassociations.com/about_us_our_team.html'],
#  ['National After School Association', 'https://naaweb.org/about-us/our-team'],
#  ['Association for Accounting Marketing',
#   'http://www.accountingmarketing.org/aboutaam/aam-headquarters'],
#  ['Society for Corporate Governance',
#   'https://www.societycorpgov.org/about/contactus'],
#  ['The National Association of Women in Construction (NAWIC)',
#   'http://www.nawic.org/nawic/Contact.asp'],
#  ['Alaska Travel Industry Association',
#   'http://www.alaskatia.org/about-us/staff-contacts'],
#  ['International Studies Association',
#   'http://www.isanet.org/ISA/Headquarters/Staff'],
#  ['American Psychiatric Association',
#   'http://www.apa.org/about/apa/senior-staff/index.aspx'],
#  ['American Association of Neuroscience Nurses (AANN)',
#   'http://aann.org/contact-us'],
#  ['National Association for Catering and Events',
#   'http://www.nace.net/contactus'],
#  ['Consortium for School Networking (CoSN)',
#   'http://www.cosn.org/about/staff'],
#  ['Indoor Air Quality Association (IAQA)', 'http://www.iaqa.org/staff/'],
#  ['Association of Nutrition & Foodservice Professionals (ANFP)',
#   'http://www.anfponline.org/about-anfp/anfp-staff'],
#  ['National Indian Education Association',
#   'http://www.niea.org/our-story/staff/'],
#  ['NIGP: The Institute for Public Procurement',
#   'http://www.nigp.org/home/about-nigp/contact/staff-directory'],
#  ['American Society of Consultant Pharmacists',
#   'http://www.ascp.com/page/whoweare'],
#  ['National Association of Stock Plan Professionals',
#   'https://www.naspp.com/miscNASPP/staff.asp'],
#  ['Association of Staff Physicial Recruiters',
#   'http://www.aspr.org/?page=staff'],
#  ['National Auctioneers Association', 'http://www.auctioneers.org/naa-staff'],
#  ['INFORMS',
#   'https://www.informs.org/About-INFORMS/Governance/INFORMS-Staff-Directors'],
#  ['American Art Therapy Association (AATA)',
#   'https://arttherapy.org/national-staff/'],
#  ['International Association of Forensic Nurses',
#   'http://www.forensicnurses.org/?page=Staff'],
#  ['Urgent Care Association of America',
#   'http://www.ucaoa.org/staff/default.asp?'],
#  ['National Emergency Number Association (NENA)',
#   'https://www.nena.org/?page=nenastaff'],
#  ['Architectural Woodwork Institute (AWI)',
#   'http://www.awinet.org/content.asp?contentid=4'],
#  ['Association for Information Systems', 'http://aisnet.org/page/ContactUs'],
#  ['Association of Professional Genealogists',
#   'https://www.apgen.org/contact.html'],
#  ['Chartered Alternative Investment Analyst Association',
#   'https://caia.org/about/leadership'],
#  ['Association of Community Cancer Centers (ACCC)',
#   'https://www.accc-cancer.org/about/Staff.asp'],
#  ['International Coach Federation (ICF)',
#   'https://www.coachfederation.org/headercontent.cfm?ItemNumber=2222'],
#  ["Professional Risk Managers' International Association (PRMIA)",
#   'http://www.prmia.org/staff'],
#  ['Alliance of Merger & Acquisition Advisors',
#   'http://www.amaaonline.com/alliance-staff/'],
#  ['Association Headquarters Inc',
#   'https://ahredchair.com/solutions/speakers-bureau'],
#  ['PRRI Association Management', 'http://prri.com/About/Team.cgi'],
#  ['California Speech-Language-Hearing Association',
#   'https://www.csha.org/About-Us/Who-is-CSHA/Staff'],
#  ['The Association of LGBTQ Journalists (NLGJA)',
#   'http://www.nlgja.org/about/nlgja-national-office-staff/'],
#  ['Alabama Society of Professional Land Surveyors (ASPLS)',
#   'https://www.aspls.org/Contact'],
#  ['National Chimney Sweep Guild', 'http://www.ncsg.org/staff.html'],
#  ['IEEE Communications Society', 'http://www.comsoc.org/staff'],
#  ['American Association of Equine Practitioners (AAEP)',
#   'https://aaep.org/about-aaep/our-team'],
#  ['National Association of Landscape Professionals (NALP)',
#   'https://www.landscapeprofessionals.org/nalp/nalp/about/contact.aspx'],
#  ['Association for Research in Vision and Ophthalmology',
#   'http://www.arvo.org/About_ARVO/Who_We_Are/Contact_us/'],
#  ['Indiana Soybean Alliance', 'http://www.indianasoybean.com/about-us/staff'],
#  ['The Brewers Association',
#   'https://www.brewersassociation.org/brewers-association/staff/'],
#  ['Dairy Management, Inc.', 'https://www.dairy.org/contact-us'],
#  ['National Association of Community Health Centers (NACHC)',
#   'http://www.nachc.org/about-nachc/staff-directory/'],
#  ['National Council for Behavioral Health',
#   'https://www.thenationalcouncil.org/about/national-mental-health-association/executives/'],
#  ['National Federation of State High School Associations',
#   'https://www.nfhs.org/who-we-are/Staff'],
#  ['American Motorcyclist Association',
#   'http://www.americanmotorcyclist.com/About-The-AMA/AMA-Board-of-Directors'],
#  ['American Optometric Association',
#   'https://www.aoa.org/advocacy/advocacy-staff-contacts'],
#  ['American Public Transportation Association',
#   'http://www.apta.com/about/contact/Pages/StaffbyDepartment.aspx'],
#  ['American Society of Plastic Surgeons',
#   'https://www.plasticsurgery.org/about-asps/leadership/senior-management-team'],
#  ['Associated Builders and Contractors (ABC)',
#   'http://www.abc.org/en-us/abc/leadership.aspx'],
#  ['Council of Better Business Bureaus',
#   'https://www.bbb.org/council/about/council-of-better-business-bureaus/cbbb-management-team/beverly-baskin/'],
#  ['CCIM Institute', 'http://www.ccim.com/about-ccim/staff/'],
#  ['Association of Public-Safety Communications Officials International (APCO)',
#   'https://www.apcointl.org/about-apco/apco-people/staff.html'],
#  ['Institute for Supply Management',
#   'https://www.instituteforsupplymanagement.org/about/content.cfm?ItemNumber=30147&RDtoken=60676&userID=&navItemNumber=30179'],
#  ['Aircraft Owners and Pilots Association',
#   'https://www.aopa.org/about/meet-the-aopa-management-team'],
#  ['Armed Forces Communications and Electronics Association (AFCEA)',
#   'https://www.afcea.org/site/BoardOfDirectors'],
#  ['American Association of Clinical Endocrinologists',
#   'http://am.aace.com/syllabus/staff'],
#  ['American Association of School Librarians',
#   'http://www.ala.org/aasl/about/staff'],
#  ['American College of Emergency Physicians (ACEP)',
#   'https://www.acep.org/About-Us/Staff-Directory/']]
